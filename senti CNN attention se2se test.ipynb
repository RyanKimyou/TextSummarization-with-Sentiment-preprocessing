# %%
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are"
}
def clean_text(text, remove_stopwords):
    '''Remove unwanted characters, stopwords, and format the text to create fewer nulls word embeddings'''
    
    # Convert words to lower case
    text = text.lower()
    
    # Replace contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    
    # Optionally, remove stop words
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text
from pickle import load 
# load from file
stories = load(open('cnn_dataset.pkl', 'rb'))
print('Loaded Stories %d' % len(stories))

st = []
ab = []
for i in range(len(stories)):
    
    a,b = list(stories[i].values())
    st.append(a)
    ab.append(b)
    
s = []
for i in range(len(st)):
    s.append(", ".join(st[i]))
    
a = []
for i in range(len(st)):
    a.append(", ".join(ab[i]))
# Out:
# Loaded Stories 92579

# %%
s[0]
# Out:
# 'its official us president barack obama wants lawmakers to weigh in on whether to use military force in syria, obama sent a letter to the heads of the house and senate on saturday night hours after announcing that he believes military action against syrian targets is the right step to take over the alleged use of chemical weapons, the proposed legislation from obama asks congress to approve the use of military force to deter disrupt prevent and degrade the potential for future uses of chemical weapons or other weapons of mass destruction, its a step that is set to turn an international crisis into a fierce domestic political battle, there are key questions looming over the debate what did un weapons inspectors find in syria what happens if congress votes no and how will the syrian government react, in a televised address from the white house rose garden earlier saturday the president said he would take his case to congress not because he has to but because he wants to, while i believe i have the authority to carry out this military action without specific congressional authorization i know that the country will be stronger if we take this course and our actions will be even more effective he said we should have this debate because the issues are too big for business as usual, obama said top congressional leaders had agreed to schedule a debate when the body returns to washington on september the senate foreign relations committee will hold a hearing over the matter on tuesday sen robert menendez said, transcript read obamas full remarks, syrian crisis latest developments, un inspectors leave syria, obamas remarks came shortly after un inspectors left syria carrying evidence that will determine whether chemical weapons were used in an attack early last week in a damascus suburb, the aim of the game here the mandate is very clear and that is to ascertain whether chemical weapons were used and not by whom un spokesman martin nesirky told reporters on saturday, but who used the weapons in the reported toxic gas attack in a damascus suburb on august has been a key point of global debate over the syrian crisis, top us officials have said theres no doubt that the syrian government was behind it while syrian officials have denied responsibility and blamed jihadists fighting with the rebels, british and us intelligence reports say the attack involved chemical weapons but un officials have stressed the importance of waiting for an official report from inspectors, the inspectors will share their findings with un secretarygeneral ban kimoon ban who has said he wants to wait until the un teams final report is completed before presenting it to the un security council, the organization for the prohibition of chemical weapons which nine of the inspectors belong to said saturday that it could take up to three weeks to analyze the evidence they collected, it needs time to be able to analyze the information and the samples nesirky said, he noted that ban has repeatedly said there is no alternative to a political solution to the crisis in syria and that a military solution is not an option, bergen syria is a problem from hell for the us, obama this menace must be confronted, obamas senior advisers have debated the next steps to take and the presidents comments saturday came amid mounting political pressure over the situation in syria some us lawmakers have called for immediate action while others warn of stepping into what could become a quagmire, some global leaders have expressed support but the british parliaments vote against military action earlier this week was a blow to obamas hopes of getting strong backing from key nato allies, on saturday obama proposed what he said would be a limited military action against syrian president bashar alassad any military attack would not be openended or include us ground forces he said, syrias alleged use of chemical weapons earlier this month is an assault on human dignity the president said, a failure t ...

# %%
#clean_texts[:2]
del_s = []
for i in range(len(st)-1):    
    if len(st[i])<= 3:
        del_s.append(st[i])
        del st[i]
        del ab[i]
            #del ab[i]

# %%
print(len(st),len(ab))
del_s
# Out:
# 92309 92309
# [[]]

# %%
lst = [[st[i][a] for a in range(2)] for i in range(len(st))]

# %%
lst_e = [[st[i][a] for a in range(2,len(st[i]))] for i in range(len(st))]

# %%
from nltk.tokenize import word_tokenize

x = [word_tokenize(d) for d in lst[0]]
len(lst)
# Out:
# 92309

# %%
lst[0]
# Out:
# ['its official us president barack obama wants lawmakers to weigh in on whether to use military force in syria',
#  'obama sent a letter to the heads of the house and senate on saturday night hours after announcing that he believes military action against syrian targets is the right step to take over the alleged use of chemical weapons']

# %%
import timeit
# %matplotlib inline
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer as sia
start = timeit.default_timer()
import pandas as pd
#Your statements here


sid=sia()
sentiment_com=[]
sentiment_pos=[]
sentiment_neg=[]
sentiment_neu=[]
script=[]
senti_list=[]
for i in range(len(lst_e)):
    word_ = lst_e[i]
    sentiment_com=[]
    sentiment_pos=[]
    sentiment_neg=[]
    sentiment_neu=[]
    script=[]
    for word in word_:
    #print(word)
        ss = sid.polarity_scores(word)
        sentiment_com.append(ss['compound'])        
        sentiment_pos.append(ss['pos'])
        sentiment_neg.append(ss['neg'])
        sentiment_neu.append(ss['neu'])
        script.append(word)
    #print(ss)
    #com_len = len(sentiment_com)
    #pos_len = len(sentiment_pos)
    #neg_len = len(sentiment_neg_
    #neu_len = len(sentiment_neu)
    #sc_len =len(script)
    percentile_list = pd.DataFrame(
    {
     'sentiment_sc': sentiment_com,
     'sentiment_pos': sentiment_pos,
     'sentiment_neg': sentiment_neg,
     'sentiment_neu': sentiment_neu,
     'script': script
    })
    senti_list.append(percentile_list)
    #print(script) 
    
    
print("success-----")
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# success-----
# Time:  533.5293787032551

# %%
import timeit

start = timeit.default_timer()

scipt_prepro= []
#for a in range(len(senti_list)):   
for a in range(len(senti_list)):      
    aaa= []
    for i in range(len(senti_list[a]["sentiment_sc"] )-1):
        bbb = senti_list[a]["sentiment_sc"][i] - senti_list[a]["sentiment_sc"][i+1]
        aaa.append(abs(bbb))

    #print(aaa)

                   
    abb = max((aaa))
    for c in range(len(aaa)):
        if abb == aaa[c]:
            #print(i)
            df_1 = senti_list[a][senti_list[a].index == c]
            #print(1)
            df_2 = senti_list[a][senti_list[a].index == c+1]
            
            break

    
    modDfObj1 = df_1.append(df_2 , ignore_index=True)
    scipt_prepro.append(modDfObj1)

    
print("success-----")
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# success-----
# Time:  114.75235067480651

# %%
lst_=[]
for i in range(len(scipt_prepro)):
    for a in range(len(scipt_prepro[i]["script"])):
        lst[i].append(scipt_prepro[i]["script"][a])

# %%
asda=[]
for i in range(len(lst)):
    asda.append([word_tokenize(d) for d in lst[i]])
    
   
dd = []
for i in range(len(asda)):
    for a in range(len(asda[i])):
        dd.append(len(asda[i][a]))
        
cc = []
for b in range(0,369236,4):
    cc.append(dd[b]+dd[b+1]+dd[b+2]+dd[b+3])
len(cc)
# Out:
# 92309

# %%
#st = []
#ab = []
'''for i in range(len(stories)):
    
    a,b = list(stories[i].values())
    st.append(a)
    ab.append(b)'''
    
s = []
for i in range(len(lst)):
    s.append(", ".join(lst[i]))
    
a = []
for i in range(len(ab)):
    a.append(", ".join(ab[i]))

# %%
s[0]
# Out:
# 'its official us president barack obama wants lawmakers to weigh in on whether to use military force in syria, obama sent a letter to the heads of the house and senate on saturday night hours after announcing that he believes military action against syrian targets is the right step to take over the alleged use of chemical weapons, some global leaders have expressed support but the british parliaments vote against military action earlier this week was a blow to obamas hopes of getting strong backing from key nato allies, on saturday obama proposed what he said would be a limited military action against syrian president bashar alassad any military attack would not be openended or include us ground forces he said'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.python.layers.core import Dense
from tensorflow.python.ops.rnn_cell_impl import _zero_state_tensors
import re
from nltk.corpus import stopwords
import time
print('TensorFlow Version: {}'.format(tf.__version__))
import csv
'''#Cell 9:'''
clean_summaries = []
for summary in a:
    clean_summaries.append(clean_text(str(summary), remove_stopwords=False))
print("Summaries are complete.")

clean_texts = []
for text in s:
    clean_texts.append(clean_text(str(text), remove_stopwords=True))
print("Texts are complete.")
# Out:
# TensorFlow Version: 1.12.0
# Summaries are complete.
# Texts are complete.

# %%
clean_texts[1]
# Out:
# 'usain bolt rounded world championships sunday claiming third gold moscow anchored jamaica victory mens relay fastest man world charged clear united states rival justin gatlin jamaican quartet nesta carter kemar baileycole nickel ashmeade bolt seconds victory never seriously doubt got baton safely hand ashmeade gatlin united states third leg runner rakieem salaam problems gatlin strayed lane struggled get full control baton never able get terms bolt'

# %%
clean_texts[:2]
a = []
for i in range(len(clean_texts)-1):
    if len(clean_texts[i])<= 1:
            a.append(clean_texts[i])
            del clean_texts[i]
            del clean_summaries[i]

# %%
print(len(clean_texts),len(clean_summaries))
# Out:
# 92309 92309

# %%
clean_summaries[80000]
# Out:
# 'plastiki will end journey in sydney  ship is made of more than plastic bottles  expedition leader says he was inspired by a un report on littering'

# %%
from nltk.tokenize import word_tokenize
import re
import collections
import pickle
import numpy as np
from gensim.models.keyedvectors import KeyedVectors
from gensim.test.utils import get_tmpfile
from gensim.scripts.glove2word2vec import glove2word2vec


#train_article_path = "sumdata/train/train.article.txt"
#train_title_path = "sumdata/train/train.title.txt"
#valid_article_path = "sumdata/train/valid.article.filter.txt"
#valid_title_path = "sumdata/train/valid.title.filter.txt"


def clean_str(sentence):
    sentence = re.sub("[#.]+", "#", sentence)
    return sentence


def get_text_list(a, b, toy):
    #with open (data_path, "r", encoding="utf-8") as f:
    if not toy:
        return [clean_str(x.strip()) for x in f.readlines()]
    else:
        return [clean_str(x.strip()) for x in f.readlines()][:80000]


def build_dict(step, toy=False):
    if step == "train":
        
        #train_article_list = get_text_list(train_article_path, toy)
        #train_title_list = get_text_list(train_title_path, toy)
        
        
        words = list()
        for sentence in clean_texts[:70000] +clean_summaries[:70000]:
            for word in word_tokenize(sentence):
                words.append(word)

        word_counter = collections.Counter(words).most_common()
        word_dict = dict()
        word_dict["<padding>"] = 0
        word_dict["<unk>"] = 1
        word_dict["<s>"] = 2
        word_dict["</s>"] = 3
        for word, _ in word_counter:
            word_dict[word] = len(word_dict)

        with open("word_dict.pickle", "wb") as f:
            pickle.dump(word_dict, f)

    elif step == "valid":
        with open("word_dict.pickle", "rb") as f:
            word_dict = pickle.load(f)

    reversed_dict = dict(zip(word_dict.values(), word_dict.keys()))

    article_max_len = 130
    summary_max_len = 20

    return word_dict, reversed_dict, article_max_len, summary_max_len


def build_dataset(step, word_dict, article_max_len, summary_max_len, toy=False):
    if step == "train":
        #article_list = get_text_list(train_article_path, toy)
        #title_list = get_text_list(train_title_path, toy)
        clean_texts[:70000]
        clean_summaries[:70000]
    elif step == "valid":
        article_list = get_text_list(valid_article_path, toy)
    else:
        raise NotImplementedError

    x = [word_tokenize(d) for d in clean_texts[:70000]]
    x = [[word_dict.get(w, word_dict["<unk>"]) for w in d] for d in x]
    x = [d[:article_max_len] for d in x]
    x = [d + (article_max_len - len(d)) * [word_dict["<padding>"]] for d in x]
    
    if step == "valid":
        return x
    else:        
        y = [word_tokenize(d) for d in clean_summaries[:70000]]
        y = [[word_dict.get(w, word_dict["<unk>"]) for w in d] for d in y]
        y = [d[:(summary_max_len - 1)] for d in y]
        return x, y


def batch_iter(inputs, outputs, batch_size, num_epochs):
    inputs = np.array(inputs)
    outputs = np.array(outputs)

    num_batches_per_epoch = (len(inputs) - 1) // batch_size + 1
    for epoch in range(num_epochs):
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, len(inputs))
            yield inputs[start_index:end_index], outputs[start_index:end_index]


def get_init_embedding(reversed_dict, embedding_size):
    glove_file = "glove.42B.300d.txt"
    word2vec_file = get_tmpfile("word2vec_format.vec")
    glove2word2vec(glove_file, word2vec_file)
    print("Loading Glove vectors...")
    word_vectors = KeyedVectors.load_word2vec_format(word2vec_file)

    word_vec_list = list()
    for _, word in sorted(reversed_dict.items()):
        try:
            word_vec = word_vectors.word_vec(word)
        except KeyError:
            word_vec = np.zeros([embedding_size], dtype=np.float32)

        word_vec_list.append(word_vec)

    # Assign random vector to <s>, </s> token
    word_vec_list[2] = np.random.normal(0, 1, embedding_size)
    word_vec_list[3] = np.random.normal(0, 1, embedding_size)

    return np.array(word_vec_list)
#tf.get_variable_scope().reuse_variables()
# Out:
# C:\Users\user\Anaconda3\envs\tf-gpu\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
print("Building dictionary...")
word_dict, reversed_dict, article_max_len, summary_max_len = build_dict("train", toy=True)
print("Loading training dataset...")
train_x, train_y = build_dataset("train", word_dict, article_max_len, summary_max_len, toy=True)
# Out:
# Building dictionary...
# Loading training dataset...

# %%
print(len(reversed_dict))
# Out:
# 144571

# %%
from nltk.tokenize import word_tokenize
import re
import collections
import pickle
import numpy as np
from gensim.models.keyedvectors import KeyedVectors
from gensim.test.utils import get_tmpfile
from gensim.scripts.glove2word2vec import glove2word2vec


#train_article_path = "sumdata/train/train.article.txt"
#train_title_path = "sumdata/train/train.title.txt"
#valid_article_path = "sumdata/train/valid.article.filter.txt"
#valid_title_path = "sumdata/train/valid.title.filter.txt"


def clean_str(sentence):
    sentence = re.sub("[#.]+", "#", sentence)
    return sentence


def get_text_list(a, b, toy):
    #with open (data_path, "r", encoding="utf-8") as f:
    if not toy:
        return [clean_str(x.strip()) for x in f.readlines()][50000:]
    else:
        return [clean_str(x.strip()) for x in f.readlines()][:80000]


def build_dict(step, toy=False):
    if step == "train":
        
        #train_article_list = get_text_list(train_article_path, toy)
        #train_title_list = get_text_list(train_title_path, toy)
        
        
        words = list()
        for sentence in clean_texts[70000:] + clean_summaries[70000:]:
            for word in word_tokenize(sentence):
                words.append(word)

        word_counter = collections.Counter(words).most_common()
        word_dict = dict()
        word_dict["<padding>"] = 0
        word_dict["<unk>"] = 1
        word_dict["<s>"] = 2
        word_dict["</s>"] = 3
        for word, _ in word_counter:
            word_dict[word] = len(word_dict)

        with open("word_dict.pickle", "wb") as f:
            pickle.dump(word_dict, f)

    elif step == "valid":
        with open("word_dict.pickle", "rb") as f:
            word_dict = pickle.load(f)

    reversed_dict = dict(zip(word_dict.values(), word_dict.keys()))

    article_max_len = 130
    summary_max_len = 20

    return word_dict, reversed_dict, article_max_len, summary_max_len


def build_dataset(step, word_dict, article_max_len, summary_max_len, toy=False):
    if step == "train":
        #article_list = get_text_list(train_article_path, toy)
        #title_list = get_text_list(train_title_path, toy)
        clean_texts[70000:]
        clean_summaries[70000:]
    elif step == "valid":
        clean_texts[70000:]
    else:
        raise NotImplementedError

    x = [word_tokenize(d) for d in clean_texts[70000:]]
    x = [[word_dict.get(w, word_dict["<unk>"]) for w in d] for d in x]
    x = [d[:article_max_len] for d in x]
    x = [d + (article_max_len - len(d)) * [word_dict["<padding>"]] for d in x]
    
    if step == "valid":
        return x
    else:        
        y = [word_tokenize(d) for d in clean_summaries[70000:]]
        y = [[word_dict.get(w, word_dict["<unk>"]) for w in d] for d in y]
        y = [d[:(summary_max_len - 1)] for d in y]
        return x, y


def batch_iter(inputs, outputs, batch_size, num_epochs):
    inputs = np.array(inputs)
    outputs = np.array(outputs)

    num_batches_per_epoch = (len(inputs) - 1) // batch_size + 1
    for epoch in range(num_epochs):
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, len(inputs))
            yield inputs[start_index:end_index], outputs[start_index:end_index]


def get_init_embedding(reversed_dict, embedding_size):
    glove_file = "glove.42B.300d.txt"
    word2vec_file = get_tmpfile("word2vec_format.vec")
    glove2word2vec(glove_file, word2vec_file)
    print("Loading Glove vectors...")
    word_vectors = KeyedVectors.load_word2vec_format(word2vec_file)

    word_vec_list = list()
    for _, word in sorted(reversed_dict.items()):
        try:
            word_vec = word_vectors.word_vec(word)
        except KeyError:
            word_vec = np.zeros([embedding_size], dtype=np.float32)

        word_vec_list.append(word_vec)

    # Assign random vector to <s>, </s> token
    word_vec_list[2] = np.random.normal(0, 1, embedding_size)
    word_vec_list[3] = np.random.normal(0, 1, embedding_size)

    return np.array(word_vec_list)
#tf.get_variable_scope().reuse_variables()

# %%
print("Loading dictionary...")
word_dict, reversed_dict, article_max_len, summary_max_len = build_dict("valid", toy=True)
print("Loading validation dataset...")
valid_x = build_dataset("valid", word_dict, article_max_len, summary_max_len, toy=True)
valid_x_len = [len([y for y in x if y != 0]) for x in valid_x]
# Out:
# Loading dictionary...
# Loading validation dataset...

# %%
print(len(reversed_dict),len(valid_x))
# Out:
# 144571 22309

# %%
import tensorflow as tf
from tensorflow.contrib import rnn
#from utils import get_init_embedding
'''
    parser.add_argument("--num_hidden", type=int, default=150, help="Network size.")
    parser.add_argument("--num_layers", type=int, default=2, help="Network depth.")
    parser.add_argument("--beam_width", type=int, default=10, help="Beam width for beam search decoder.")
    parser.add_argument("--glove", action="store_true", help="Use glove as initial word embedding.")
    parser.add_argument("--embedding_size", type=int, default=300, help="Word embedding size.")

    parser.add_argument("--learning_rate", type=float, default=1e-3, help="Learning rate.")
    parser.add_argument("--batch_size", type=int, default=64, help="Batch size.")
    parser.add_argument("--num_epochs", type=int, default=10, help="Number of epochs.")
    parser.add_argument("--keep_prob", type=float, default=0.8, help="Dropout keep prob.")

    parser.add_argument("--toy", action="store_true", help="Use only 50K samples of data")

    parser.add_argument("--with_model", action="store_true", help="Continue from previously saved model")'''
class Model(object):
    def __init__(self, reversed_dict, article_max_len, summary_max_len, forward_only=False):
        self.vocabulary_size = len(reversed_dict)
        self.embedding_size = 300
        self.num_hidden = 150
        self.num_layers = 2
        self.learning_rate = 0.001
        self.beam_width = 5
        if not forward_only:
            self.keep_prob = 0.8
        else:
            self.keep_prob = 1.0
        self.cell = tf.nn.rnn_cell.BasicLSTMCell
        with tf.variable_scope("decoder/projection"):
            self.projection_layer = tf.layers.Dense(self.vocabulary_size, use_bias=False)

        self.batch_size = tf.placeholder(tf.int32, (), name="batch_size")
        self.X = tf.placeholder(tf.int32, [None, article_max_len])
        self.X_len = tf.placeholder(tf.int32, [None])
        self.decoder_input = tf.placeholder(tf.int32, [None, summary_max_len])
        self.decoder_len = tf.placeholder(tf.int32, [None])
        self.decoder_target = tf.placeholder(tf.int32, [None, summary_max_len])
        self.global_step = tf.Variable(0, trainable=False)

        with tf.name_scope("embedding"):
            if not forward_only :
                init_embeddings = tf.constant(get_init_embedding(reversed_dict, self.embedding_size), dtype=tf.float32)
            else:
                init_embeddings = tf.random_uniform([self.vocabulary_size, self.embedding_size], -1.0, 1.0)
            #tf.get_variable_scope().reuse_variables()
            self.embeddings = tf.get_variable("embeddings", initializer=init_embeddings)

            self.encoder_emb_inp = tf.transpose(tf.nn.embedding_lookup(self.embeddings, self.X), perm=[1, 0, 2])
            self.decoder_emb_inp = tf.transpose(tf.nn.embedding_lookup(self.embeddings, self.decoder_input), perm=[1, 0, 2])

        with tf.name_scope("encoder"):
            fw_cells = [self.cell(self.num_hidden) for _ in range(self.num_layers)]
            bw_cells = [self.cell(self.num_hidden) for _ in range(self.num_layers)]
            fw_cells = [rnn.DropoutWrapper(cell) for cell in fw_cells]
            bw_cells = [rnn.DropoutWrapper(cell) for cell in bw_cells]

            encoder_outputs, encoder_state_fw, encoder_state_bw = tf.contrib.rnn.stack_bidirectional_dynamic_rnn(
                fw_cells, bw_cells, self.encoder_emb_inp,
                sequence_length=self.X_len, time_major=True, dtype=tf.float32)
            self.encoder_output = tf.concat(encoder_outputs, 2)
            encoder_state_c = tf.concat((encoder_state_fw[0].c, encoder_state_bw[0].c), 1)
            encoder_state_h = tf.concat((encoder_state_fw[0].h, encoder_state_bw[0].h), 1)
            self.encoder_state = rnn.LSTMStateTuple(c=encoder_state_c, h=encoder_state_h)

        with tf.name_scope("decoder"), tf.variable_scope("decoder") as decoder_scope:
            decoder_cell = self.cell(self.num_hidden * 2)

            if not forward_only:
                attention_states = tf.transpose(self.encoder_output, [1, 0, 2])
                attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                    self.num_hidden * 2, attention_states, memory_sequence_length=self.X_len, normalize=True)
                decoder_cell = tf.contrib.seq2seq.AttentionWrapper(decoder_cell, attention_mechanism,
                                                                   attention_layer_size=self.num_hidden * 2)
                initial_state = decoder_cell.zero_state(dtype=tf.float32, batch_size=self.batch_size)
                initial_state = initial_state.clone(cell_state=self.encoder_state)
                helper = tf.contrib.seq2seq.TrainingHelper(self.decoder_emb_inp, self.decoder_len, time_major=True)
                decoder = tf.contrib.seq2seq.BasicDecoder(decoder_cell, helper, initial_state)
                outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(decoder, output_time_major=True, scope=decoder_scope)
                self.decoder_output = outputs.rnn_output
                self.logits = tf.transpose(
                    self.projection_layer(self.decoder_output), perm=[1, 0, 2])
                self.logits_reshape = tf.concat(
                    [self.logits, tf.zeros([self.batch_size, summary_max_len - tf.shape(self.logits)[1], self.vocabulary_size])], axis=1)
            else:
                tiled_encoder_output = tf.contrib.seq2seq.tile_batch(
                    tf.transpose(self.encoder_output, perm=[1, 0, 2]), multiplier=self.beam_width)
                tiled_encoder_final_state = tf.contrib.seq2seq.tile_batch(self.encoder_state, multiplier=self.beam_width)
                tiled_seq_len = tf.contrib.seq2seq.tile_batch(self.X_len, multiplier=self.beam_width)
                attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                    self.num_hidden * 2, tiled_encoder_output, memory_sequence_length=tiled_seq_len, normalize=True)
                decoder_cell = tf.contrib.seq2seq.AttentionWrapper(decoder_cell, attention_mechanism,
                                                                   attention_layer_size=self.num_hidden * 2)
                initial_state = decoder_cell.zero_state(dtype=tf.float32, batch_size=self.batch_size * self.beam_width)
                initial_state = initial_state.clone(cell_state=tiled_encoder_final_state)
                decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                    cell=decoder_cell,
                    embedding=self.embeddings,
                    start_tokens=tf.fill([self.batch_size], tf.constant(2)),
                    end_token=tf.constant(3),
                    initial_state=initial_state,
                    beam_width=self.beam_width,
                    output_layer=self.projection_layer
                )
                outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
                    decoder, output_time_major=True, maximum_iterations=summary_max_len, scope=decoder_scope)
                self.prediction = tf.transpose(outputs.predicted_ids, perm=[1, 2, 0])

        with tf.name_scope("loss"):
            if not forward_only:
                crossent = tf.nn.sparse_softmax_cross_entropy_with_logits(
                    logits=self.logits_reshape, labels=self.decoder_target)
                weights = tf.sequence_mask(self.decoder_len, summary_max_len, dtype=tf.float32)
                self.loss = tf.reduce_sum(crossent * weights / tf.to_float(self.batch_size))

                params = tf.trainable_variables()
                gradients = tf.gradients(self.loss, params)
                clipped_gradients, _ = tf.clip_by_global_norm(gradients, 5.0)
                optimizer = tf.train.AdamOptimizer(self.learning_rate)
                self.update = optimizer.apply_gradients(zip(clipped_gradients, params), global_step=self.global_step)



#with tarfile.open("summary.tar.gz", "r:gz") as tar:
#    tar.extractall()

#with gzip.open("sumdata/train/train.article.txt.gz", "rb") as gz:
#    with open("sumdata/train/train.article.txt", "wb") as out:
#        out.write(gz.read())

#with gzip.open("sumdata/train/train.title.txt.gz", "rb") as gz:
#    with open("sumdata/train/train.title.txt", "wb") as out:
#        out.write(gz.read())

# %%
with tf.Session() as sess:
    print("Loading saved model...")
    model = Model(reversed_dict, article_max_len, summary_max_len, forward_only=True)
    saver = tf.train.Saver(tf.global_variables())
    ckpt = tf.train.get_checkpoint_state("./saved_model/")
    saver.restore(sess, ckpt.model_checkpoint_path)
    #saver = tf.train.Saver()
    #saver.restore(sess, "./saved_model/model.ckpt")

    batches = batch_iter(valid_x, [0] * len(valid_x), 64, 1)

    print("Writing summaries to 'result.txt'...")
    for batch_x, _ in batches:
        batch_x_len = [len([y for y in x if y != 0]) for x in batch_x]

        valid_feed_dict = {
            model.batch_size: len(batch_x),
            model.X: batch_x,
            model.X_len: batch_x_len,
        }
        #sess.run(tf.global_variables_initializer())
        prediction = sess.run(model.prediction, feed_dict=valid_feed_dict)
        prediction_output = [[reversed_dict[y] for y in x] for x in prediction[:, 0, :]]

        with open("result_senti_130_20.txt", "a",encoding='UTF-8') as f:
            for line in prediction_output:
                summary = list()
                for word in line:
                    if word == "</s>":
                        break
                    if word not in summary:
                        summary.append(word)
                print(" ".join(summary), file=f)

    print('Summaries are saved to "result.txt"...')
# Out:
# Loading saved model...
# WARNING:tensorflow:From <ipython-input-27-a7deb699ba5c>:55: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# INFO:tensorflow:Restoring parameters from ./saved_model/model.ckpt-175040
# Writing summaries to 'result.txt'...
# Summaries are saved to "result.txt"...

# %%
crimefile = open("C:/Users/user/result_senti_130_20.txt", 'r')
yourResult = [line.split(',') for line in crimefile.readlines()]

#line = pre.strip()
final_list = []
for i in range(len(yourResult)):
     final_list.append(yourResult[i][0].rstrip())

# %%
len(final_list)
# Out:
# 22309

# %%
def get_rouge_scores(preds, hyps, avg=True):
    if len(hyps) != len(preds):
            p_len = len(preds)
            hyps = hyps[:p_len]  
    rouge = Rouge()
    print("Calculating rouge scores...")
    scores = rouge.get_scores(hyps, preds, avg=avg)
    return scores
from rouge import Rouge
print(len(final_list))
print(len(clean_summaries[70000:]))
get_rouge_scores(clean_summaries[70000:], final_list, avg=True)
# Out:
# 22309
# 22309
# Calculating rouge scores...
# {'rouge-1': {'f': 0.1619892054492815,
#   'p': 0.25575845680849096,
#   'r': 0.12088406020506597},
#  'rouge-2': {'f': 0.038871780529047995,
#   'p': 0.06642726313688048,
#   'r': 0.028026080150928504},
#  'rouge-l': {'f': 0.10661382702518293,
#   'p': 0.2032639562109818,
#   'r': 0.09694913224222433}}

# %%
clean_summaries[70003]
# Out:
# 'the daily transcript is a written version of each days cnn student news program  use this transcript to help students with reading comprehension and vocabulary  use the weekly newsquiz to test your knowledge of stories you saw on cnn student news'

# %%
crimefile = open("C:/Users/user/result_senti_130_20.txt", 'r')
yourResult = [line.split(',') for line in crimefile.readlines()]
crimefile1 = open("C:/Users/user/result_normal_130_20.txt", 'r')
yourResult1 = [line.split(',') for line in crimefile1.readlines()]

# %%
yourResult
# Out:
# [['sen barack obama hopes to vote when his exit and senate candidates go mccain says\n'],
#  ['some expensive restaurants are having a christmas and drink company captures street touch the proposal is still in\n'],
#  ['william bloom asks we have to address climate change what more support says might make\n'],
#  ['the daily transcript is a written version of each days cnn student news program use this to help\n'],
#  ['boko haram fighters escaped in the town connection with a military official says\n'],
#  ['there is a rare video of boy removal eric k millionaire the probably for duty many\n'],
#  ['barcelona defeat rivals real madrid in la liga a group to sociedad the target is now\n'],
#  ['michael hayden says his dad being honest but he called advice for someone caused new rules\n'],
#  ['a move hattrick gives barcelona on hold ball at home athletic bilbao unveils top of\n'],
#  ['new the captain is of south korea crew says incident follows rescue\n'],
#  ['new streets authorities say minors finds locations including probe says thailand the conditions be exchanged to deal\n'],
#  ['real madrid survive after people died being missing for son of collapse man who falling\n'],
#  ['internet lobby lied to some religious and outages mostly catholic company says ending its recession user others\n'],
#  ['bryan and started months old is star has been pushed for march one of the season\n'],
#  ['khaled abol drew facebook and book about the gay women tried to win a sharp picture one in\n'],
#  ['driver of crash in north america injured after parts highway the from guitar gives\n'],
#  ['more than people have died in a capital fire fighting mogadishu are injured many of\n'],
#  ['brazilian football club sport dominates the according to in brazil will go ahead of\n'],
#  ['jim hall is planning video games with a resurgence in las vegas the company will feature variety of\n'],
#  ['new russian foreign ministry says the plane is carrying miles off chinas platform from indonesian capital china\n'],
#  ['the washington level is found safer than march data then went call using a cnn agency says\n'],
#  ['new talks to cnn we wrote on the ground kill people dylan says he must explain things\n'],
#  ['the united states is devastated to czech republic of tanzania a state can help bear animals in\n'],
#  ['tuesday has been set for about the day march moscow and mark omara question how\n'],
#  ['the beer was once very serious point in northern afghanistan tensions between kurds and iraq have limited\n'],
#  ['creator dave h remained popular with tech and tv the new ways customers include sharing to be\n'],
#  ['the supreme court lifts chemicals on human rights activists say courts ruling a courageous supporters in chelseas proposal\n'],
#  ['thousands of former activist director terror prompted question in arabic screening harry says he is part a\n'],
#  ['rescued island was born on july in a year of making it photographer agency said the\n'],
#  ['clashes have gone down in march organizers say an official says many states trying to calm fears\n'],
#  ['a federal crime was presented for attempted rape man found guilty of murder charges his arrest\n'],
#  ['storm avoided ohio town of jefferson miles oklahoma gets blizzard warnings affected kentucky inches rain\n'],
#  ['new alassad on syria with syrias largest opposition libya efforts seem to be used by a brutal crackdown in\n'],
#  ['alex ferguson reveals as many manchester united manager two teams that enjoyed a hole rory mcilroy and roma\n'],
#  ['hollywood killers is an part of hunger games clip a academy film for\n'],
#  ['european champions chelsea held to the pga cup final holders is banned from world qualifying against\n'],
#  ['the group makes fans like for first lady to see muslim leaders explores social\n'],
#  ['one dies in baghdad including civilians and al qaeda militants claim responsibility for the attack five wounded most\n'],
#  ['the decision cost of flooding and components sent to lower court they included a fleet\n'],
#  ['prime minister president robert mugabe is a serious escalation in the peace kenya\n'],
#  ['apple ceo steve jobs and near san francisco pro would revolutionize raises fallen at\n'],
#  ['mikhail ibrahim leads victory over turning to poor match on sunday world frenchman triumphs at no\n'],
#  ['seth meyers will be released on july day fire to escape engine cell foundation the family wanted\n'],
#  ['mark coleman announced monday of february she had a decade ago the show falls\n'],
#  ['nj michigan mayor justin sullivan does not say his boss turned up illinois indiana father tells the cops in\n'],
#  ['rice suffers from dropping so he says obamas victory at werder bremen obama has kept iran arctic next month\n'],
#  ['while promoting an art room that display up for modern traffic chinese designers to have perform sentences in\n'],
#  ['susan atkins has spoken of the crime center parole walker confirmed that is linked to die in\n'],
#  ['the flame leagues path to cover of ice from dogs in rio de janeiro russia took over\n'],
#  ['nearly double surgeries in the rubble of haiti quake people were injured\n'],
#  ['craig brown one month videos show teachers with urban tolerance time lz granderson says town used to protect\n'],
#  ['arsene wenger speaks out of englands players game the match is expecting a victory over london\n'],
#  ['one soldier is the third daughter of killing near border area no found in\n'],
#  ['us supreme court justice edward james provided legal to prosecute citizens department says its ruling by\n'],
#  ['womans girl is due in court hours to closing the time touch down she\n'],
#  ['willie tom feels out of brazils pit smith speaks cnns brian williams brown addressed an outpatient substance\n'],
#  ['remarkable john romney not ready to interview the economy emotional deficit is a difference between three months says\n'],
#  ['officials say the comedian is a lost student robyn gardner was investigated following review of her teams dad\n'],
#  ['authorities are planning to release people but china has seen crimes yet north leader jesse says he wont\n'],
#  ['airline rolled out one week at just four pilots angry about flying safety the said it was\n'],
#  ['new he believes worked smoking in which the state park defense dna is accused of trying to\n'],
#  ['the judge will continue trial of pistorius and prison judges were rejected by\n'],
#  ['radovan karadzic faces charges of srebrenica massacre in he was killed us against the alleged criminal\n'],
#  ['cnns arwa damon picture showed the biggest social crisis of iraq and middle east have been diverse\n'],
#  ['mayor michael bloomberg says he couldnt lift his message to diner and dallas times returned\n'],
#  ['israel plans to defend front power analyst says deals wrongly he seems like be the\n'],
#  ['a prosecutors file say the former grand jury has been told to close bribes state youth community\n'],
#  ['secretary of state john kerry says hell say he is on a possible deal exit\n'],
#  ['alex ferguson is expected to play in a club at manchester united million end on\n'],
#  ['roger federer criticizes bidding number of claims that the tournament fred or damages wins all over\n'],
#  ['cnns girl rising star sparks a metal walk with lebanon pm david cameron had shoulder injury after\n'],
#  ['some magazine might find a new model of how to piece ice creators see it and\n'],
#  ['manchester striker carlos tevez scores a hattrick as bale died after defeat by milan the arsenal had lost\n'],
#  ['the us constitution as a trial of efrain rios montt was first leader rome decision he\n'],
#  ['cnns jeff jack became a professional soccer player in this earlier years child he says lot of\n'],
#  ['researcher police say it took him from toward a trail of where perry about the\n'],
#  ['donna brazile in some as make it be a success he says but there are no of\n'],
#  ['vbs crew on earth meg urry his huge reaction from the mediterranean karen explores nearly half\n'],
#  ['man lands on the moon july with apollo mission a new supreme court justice and withdrawal of troops\n'],
#  ['katherine jackson some of the people who worked out suicide bombers arent included in my life i have\n'],
#  ['refusing to kill an oklahoma town near pm et if you cant be afraid think about your ears\n'],
#  ['taylor was stabbed at her hospital los angeles single pill not been a\n'],
#  ['the pope says francis sends message to blame he a lot of people have\n'],
#  ['new at least people have been killed in a tsunami no and will be declared on sunday\n'],
#  ['magic resort is an annual travel industry competition and north america could be held in korea matthew adams\n'],
#  ['us marine navy corps was searching the two american soldiers were killed operations seven\n'],
#  ['new president tweets dead his claim rise of ebola cuban leader who is\n'],
#  ['london lives with japan as being tested positive for well the time he is first\n'],
#  ['new searcher says location is likely to find ocean suspicious search agency finds no criminal data from europe\n'],
#  ['david frum he didnt remember right to have a credit system says some officials say there is\n'],
#  ['china says his legacy of chinese president hu jintao ends hometown xinjiang province group killed\n'],
#  ['new white house spokesman says the woman was arrested early saturday no female officer underwent test harm weapons\n'],
#  ['new there are no immediate reports about a tsunami alert in the us epicenter was miles northeast is\n'],
#  ['angela merkel leads ceremonies to mark years since collapse of berlin wall thousands people converged on symbolic brandenburg\n'],
#  ['military says there is still hard expert was a violation of the troops lt gen kelly\n'],
#  ['new official yorks mayor is set to lift the sentence law will go into effect next week\n'],
#  ['obama says voters likely to vote for in elections outcome still could be president polls show\n'],
#  ['german tragedy in a texas pastors wife that of civil war was destroyed the world\n'],
#  ['michael jacksons dance moves his look were emulated jackson inspired artists such as usher justin timberlake and rapper snoop\n'],
#  ['the newspaper says people have supported some ask about tactics from lahore it just things larry king\n'],
#  ['a top chair bars researchers on the planet of christmas world contest great study is installing\n'],
#  ['with a massive steep hit by the city of year it does not have more\n'],
#  ['elton john and philip have inspired british artists to songs in the universe today with both\n'],
#  ['pope francis and the of st louis cardinals have expressed change latin american sea a source\n'],
#  ['daughter of her husband diane guerrero says helped face a man she is in italy after\n'],
#  ['new the woman and girl will not have a bond sunday police say male bail comes friday\n'],
#  ['sally kohn the supreme court could provide lincoln to donna anne levels such as decision on\n'],
#  ['author bible age of religious stories wrote on why she says i saw the love year\n'],
#  ['lower manhattan is law finds highly independent review of the brain alert study it too extreme as\n'],
#  ['relatives of the cdc boys and their families since two men they type to kill\n'],
#  ['charlie hebdo releases a photo of himself at police age the presence three it was\n'],
#  ['mumbais taj mahal palace tower oberoitrident luxury hotels reopen both were targeted by gunmen in last months attacks\n'],
#  ['a search for the suicide bomber never passed same time of crashed plane worried\n'],
#  ['national transportation safety board released after agency says problems the homeland security will still be able\n'],
#  ['charles wrote of the son president obama his will bring\n'],
#  ['club to appoint premier league leaders from carlos tevez on wednesday manchester city had been moving one percent\n'],
#  ['white president boris signs kidnapping powers of his role in darfur lee myungbak praises special interests peace talks\n'],
#  ['the english world cup has been compared to a recent exhibition of worlds billionaires euro lists have\n'],
#  ['manuel noriega is in bogota with panama but the suspension will be extradited wrights house arrest of shonan maru\n'],
#  ['five cases of a month is under age from sex trafficking case man writes he investigation\n'],
#  ['officer of a basketball player george wrongly whom he supports the truth says bob greene teachers work but\n'],
#  ['lewis hamilton will miss the pole for next season be nine points with\n'],
#  ['the paintings by museum is still a marked august for him john franklin iii awarded games\n'],
#  ['man has pleaded guilty to charges of aiding al qaeda bryant neal vinas interview with crowds a cell\n'],
#  ['new hip hop service says lindsay lohan took control of her sexual encounter with a teen one music\n'],
#  ['researchers say its messenger app allowing users to fight spread of illegal already being warned that allows\n'],
#  ['boko haram says he was kidnapped in hours by reportedly after the deal\n'],
#  ['sources pledge of peace and buildings will allow to property crowds expected build a network agreement\n'],
#  ['frances father of celina cass describes his mother and modern house in medieval water actor served with one\n'],
#  ['actions angry accused of wearing sinaloa drug cartel charges former with times in venezuela shields teen\n'],
#  ['the strike says it condemns attack and moves targets in an area one group\n'],
#  ['california is hoping to know how this economy going be certified by the changing\n'],
#  ['chelsea announces boycott fa has sent a to england for the investigation shakhtar donetsk deny allegations that\n'],
#  ['david bailey burberrys brave is a factor for disney commander hes appointed to leave the head step down\n'],
#  ['flight over european union since charles and to warn of heavy air hundreds flights had canceled most\n'],
#  ['mario balotelli is manchester united out to world cup finals the city striker has sent his only goal\n'],
#  ['i cant think of what they will get in about their new coolest jobs the founder and mother should\n'],
#  ['president obama promises plan to raise cooperation with north africa and south if africans want get done\n'],
#  ['thousands of breast cancer have been fired from up to pay at the tables a\n'],
#  ['autism is the hunger childrens stories at newtown connecticut public swimming records you have lost his life as\n'],
#  ['douglas kennedy is originally cites genetic testing for change on its she argues that it could be\n'],
#  ['new dead have been reported in the citys poor spanish series has nationwide on tuesday\n'],
#  ['authorities say a judge refuses to run for the us cruise from real estate officials have\n'],
#  ['nbc asked the emirates executive to extend its million year price fifth cnn top\n'],
#  ['some of people voted themselves in the most infamous for war it provides support free dont ask\n'],
#  ['the vessel was carrying inside sea of coast florida on friday she missing because a\n'],
#  ['congressman of federal agencies wait until some pilot gop senators say resources sens congressional negotiators he shoots\n'],
#  ['republican sen jerry yellin has been criticized for an rape he says the residents my age one\n'],
#  ['new captain pirates took off with filipinos ship themselves in the area was one of highest\n'],
#  ['nearly erupt at the animals have killed by raged for world un secretarygeneral ban appears to\n'],
#  ['jorge lorenzo wins the motogp season in at spaniard earlier\n'],
#  ['the force is first major capital for wednesday group out of tap into retail\n'],
#  ['stanford say washington penn state is playing gary university says thing for democrats were made\n'],
#  ['us geological survey says quake was imminent or damage most significant heard the\n'],
#  ['congress is considering a close relationship between jeb and george w bush not allowed to serve as selection\n'],
#  ['sothebys releases the rare critical of comic book study more than years ago author must\n'],
#  ['every year great internet wins offers free of to cities it is really easy use\n'],
#  ['champion nigeria bow out following draw with south africa controversy over guineas participation linked to ebola outbreak ivory\n'],
#  ['the head of public is set at a hearing on monday new tests find him that could increase\n'],
#  ['at aid to see violence erupts in the philippines group urges syrians sit on fire\n'],
#  ['a slow pressure is seen as likely to get so much oil in one left\n'],
#  ['tensions continue on nuclear power thursday between china and japan warn of bad control almost say\n'],
#  ['chinese police welcome their premier league for improper conduct striker is arrested\n'],
#  ['new journalist romeo langlois was on hamid dabashi deceased people were killed she protesting last month april\n'],
#  ['google leak came just at pm in china according to hotel room rules that could get you\n'],
#  ['seven eight members of history are tied for college this week the platform received an investigation into working writer\n'],
#  ['iraq killed islamist militants in baghdad neighborhood\n'],
#  ['former nfl star louis oosthuizen attacked a man at berlin event he had faced him sound and said\n'],
#  ['democratic leader barack obamas is a priority for individuals now pierre julian assange says the house doesnt buy\n'],
#  ['president obama is the times of africanamericans in election since this people have criticized because\n'],
#  ['us cargo urges iranian troops to target barbaric act of air force all raided the raid\n'],
#  ['big brother sporting events have completed their new football ring la announces winner of the liga on august\n'],
#  ['nfl states matt brady seemed to lift super bowl roxanne jones penn state coach scored in winning\n'],
#  ['a targeting of helicopters and arming terrorists in being fired on stroke for couples returning home is likely\n'],
#  ['calls for middle class was very exclusive im more unaccounted power to the east no one would\n'],
#  ['chelsea win over rivals southampton in group c day roma sent off with two points clear of\n'],
#  ['fifth hearing is being held in aftermath of his dog screaming the fort camp say neither mans wife takes\n'],
#  ['specialneeds baseball league near atlanta has nearly children some players use sports practices a wheelchair in\n'],
#  ['new one military official says clashes expected as part of the union head law both and\n'],
#  ['rand paul mitchell has made a political change to beat china it little of chance win\n'],
#  ['new obama orders us to security dogs at checkpoint government provide\n'],
#  ['northern iraq killed on commander tony blair iii named soldiers died in the investigation british makes\n'],
#  ['jean is accused of rape and other on the missouri law prosecutor will decide justice\n'],
#  ['american actors walk off the story this week it was a about of\n'],
#  ['donna brazile graham honest abe must sign other candidates to social media which can be changed care\n'],
#  ['ireporters are still very much facts father of the times eric ferguson david dean obeidallah two\n'],
#  ['new based on st moritz files for sexual misconduct the abuse is also participants settlement scheduled to\n'],
#  ['university says students left of student notes found gray campus media\n'],
#  ['multiple violations against president obama speaks with cnn on wednesday robert eric shinseki will work more in office\n'],
#  ['new evidence could be removed from several weeks as previously director representative condemns the ball statue of former president\n'],
#  ['vidalia onion committee to place cutouts of shrek in grocery stores industry say its good if appropriate for\n'],
#  ['defense is jeffrey phillips jr writes in his tackle for role iraq war has dealt\n'],
#  ['michael jackson albums dominate bestseller charts on amazoncom itunes online retailer playcom reported album sales increased by percent\n'],
#  ['the search resumes in malaysian airlines flight has been missing australian government sent plane to\n'],
#  ['downton abbey is the first wild winner in million have had\n'],
#  ['democrats are accused of conspiring to work on national interest james johnson julian zelizer it has acknowledged that george\n'],
#  ['a nba star is being held on triathlon in los angeles sacramento couple scheduled to\n'],
#  ['the national committee provides coverage of fbi review some were skeptical about proper permits\n'],
#  ['obama extends lead to a joint exercise secretary of state says and other leaders are going\n'],
#  ['owners of alleged holocaust ask for stories tell santa monica must move a successful statement in depression writer\n'],
#  ['japan is named as members of the asian nations made decision turkeys during\n'],
#  ['more than wounded in fighting established by violence every report says tens of thousands troops have taken\n'],
#  ['state department says israeli leaders call for statehood at the east am what he calls holy land is\n'],
#  ['lasers that blind pirates are opening more information available to wealthy superyacht owners the only temporarily impair eyesight\n'],
#  ['former pilot randall is being sued for many engaging in the us who broken patrick over\n'],
#  ['andy mcgraw was shot along with his neck and the actor is under fire for hartley\n'],
#  ['the florida should become a dream for their lawyers on fathers trial he was sentenced to years in\n'],
#  ['the israeli prime minister warns of notion that government is awesome to moscow oil sales and could\n'],
#  ['focus on major league baseball club to star in alex rodriguez shot off the theater pair had been convicted\n'],
#  ['officials say major militants have had responsibility for the air france is one of latest\n'],
#  ['were executed in colorado and murders a year after the january was sold gray children waiting for their organizations\n'],
#  ['bottles and water waste the chemical weapon pleads ok food nuclear power has been a\n'],
#  ['new abc will spend at least five weeks after the head of and\n'],
#  ['corps of engineers for structures destroyed by the tackle new itll make it nations next month\n'],
#  ['new a tokyo electric company blocks samples from thursday japanese spokesman says majority of all radiation\n'],
#  ['the world and economies will raise billion in development of middle class education million dollars are on\n'],
#  ['larry maritime service will host the xbox one of best in our original national viewers earns him\n'],
#  ['democrats from the senate has been dropped states democratic majority later measure also sent\n'],
#  ['michael vick to take six months of football on monday nfl coach we have a proud goal as\n'],
#  ['naacp unveils new program to allow people report alleged police misconduct texts emails can also be sent\n'],
#  ['in his home gravity are the hallmark of great robin williams has been made\n'],
#  ['canadas environmental group wins new rain on species of from york the designation is called spectacular\n'],
#  ['held by obama on his first child with the pressure penn states howard kurtz says influence\n'],
#  ['new john mccain doesnt expect child support as childrens democratic aide says hes not a ferrari in months\n'],
#  ['the daily transcript is a written version of each days cnn student news program use this to help\n'],
#  ['former boys fighting between clothes and alex ferguson victims son says lives of is dead in a\n'],
#  ['new such cia administration has ordered full ministers from senate differ on the nuclear option deal is expected to\n'],
#  ['ferrari fans will also face this season and change ahead but president luca di montezemolo move into a\n'],
#  ['twitter childs first tweet account cites an ad on outside the test voice recorder allows company to\n'],
#  ['elaine baron cohen and author norman aired his comedy the may awardwinning of rb locked in my life\n'],
#  ['testimony given at preliminary hearing for models doctors lawyer pharmacist says he was faxed list of drugs that doctor\n'],
#  ['carl safina its a common tool to have positive player of college voters in below the ranks\n'],
#  ['the meeting would have to start talks in syria some nations are expected vote since\n'],
#  ['gulf islands island nation when the and may take tour of national park bay\n'],
#  ['five months is in for nine hours dinner officials say secretary of state returns to ukraine last week\n'],
#  ['two former cia director michael douglas goes to real estate has been filed by phone with testimony against\n'],
#  ['the violence occurred in egypts suburb of ukraine people were inside streets military leaders he considers\n'],
#  ['lionel richie likes father says nicole is rush for she was tired and supporting support\n'],
#  ['new japan escalated friday after disputed islands between tensions china had said the senkaku are\n'],
#  ['south koreas military chief denies it does not watched one first presence north korea apologized to\n'],
#  ['president obama says kim jong un has rescued his message at augusta national park south koreas made jokes\n'],
#  ['american academy of dermatology tattoo regret common in the us current removal process is painful expensive timeconsuming new\n'],
#  ['new police say the suspect is alleged by in rape of sen john\n'],
#  ['the ioc to investigate olympic athletes training womens team included mens basketball won gold\n'],
#  ['peace marks the first state of emergency council discusses zone what happened in sudan\n'],
#  ['facebook is a highlight site of her lifetime via language the includes increase in times\n'],
#  ['workers are injured an internal review official says miners were fired into power and white house spokesman there\n'],
#  ['mom kim has started her in a special session she and friends have their pain drinking two\n'],
#  ['kendrick johnson was killed in the past week southwest georgia girls died of a year there\n'],
#  ['national weather service says there is a handful of airports to opt out plane transportation secretary\n'],
#  ['the bangladeshi government is humanitarian relief for being paid confirm documents say facing workers target\n'],
#  ['natalie portman says no valentines is a hoax and girl got away she was the subject of talent\n'],
#  ['senate will pay billion bill to sign proposal until issue be affected by friday\n'],
#  ['new victims father says his appeared at the home of incident happened\n'],
#  ['complains players shouldnt have used text messages made by a man being charged with racially exclusive interview advises\n'],
#  ['ibm photo kennedy fabrice muambas collapse does not help he says global concerns over the rest of indian\n'],
#  ['aclu and arab people are behind to fight terror suspects next week message is expected show a very\n'],
#  ['state department says third world congress will try to resume monday israel denies any attack on the nuclear station\n'],
#  ['sewart david nozette appeared in us federal prosecutors say he tried to kill americans on too close detonate\n'],
#  ['the decision marks start of a revolutionary role in bin ladens death al osama laden was killed\n'],
#  ['pirates grounded after near european union fishing helicopter crew finds a common sense for human error tensions\n'],
#  ['three people are killed tuesday after clashes across the british airstrike they have been witness says protesters\n'],
#  ['grandmother said she seems to be a dream idea says it is not answer take on\n'],
#  ['nasser was arrested in libya to hijacked two territorial group reports they had only said be\n'],
#  ['new al qaeda denies the death toll of attacks on shiite religious freedom bombing attack goes to\n'],
#  ['new central insight was intended for more than murders mugabe says the has been in prison\n'],
#  ['michelle obama hails an exclusive interview with her doctor in a book about life the attack on\n'],
#  ['new he doesnt give my probation and is not going to make his stop on unrelated charges says\n'],
#  ['official more than soldiers crossed a line of in the northern pakistani army\n'],
#  ['leaders in china say has been marking the anniversary of sinking chinas president xi jinping is meeting\n'],
#  ['joseph duncan committed his first sexual offense at the age of he was sentenced to death last month after\n'],
#  ['the airport fired in an unknown kenyan jet on monday station operating standards have been suspended all people\n'],
#  ['a tornado that might have been reduced for week in oklahoma texas severe flooding are reported\n'],
#  ['british and uk start treaty to expand a global health organization she says more than half of\n'],
#  ['donald white house says it is a good ready for when he you got chance to\n'],
#  ['new the man who fled dead is due to die by a serbian killed\n'],
#  ['roland martin cases suddenly weeks after luther king jr why do tavis smiley and eric palin as a\n'],
#  ['the internet in is actually a very diverse nation analyst says of atlantic city and truth are\n'],
#  ['wife of shawn sherwin labeet one officer scuba review at the shooter police say she posed with threats\n'],
#  ['before the revolution in world one year afghanistan writes car cities it comes light\n'],
#  ['un investigator of labor battle in the worst war coming up after disputed islands threeyear deal\n'],
#  ['neil peter koreas new song is offensive to combat security as it a major overhaul of\n'],
#  ['the late champions league defeat puts off final both blacks beat crown with\n'],
#  ['martin and winter concerts are finally on christmas day greene believes it will be seen at the fictional\n'],
#  ['we will not say how many count a lawyer says jordans king came days since may the report\n'],
#  ['new since sworn in as president of eastern ukraine prime minister yingluck shinawatra has held military to and is\n'],
#  ['the us military academy has been at bottom of service work on harrison ford to\n'],
#  ['new the accident was one of whales all people are injured brian todd two\n'],
#  ['barack obama and other social network unhappy with superstorm sandy american fund users have flocked to twitter kill\n'],
#  ['one analyst thousands of dollars in hometown led by author says some estate companies aim to find ways\n'],
#  ['the death of amanda knox was convicted killing a woman according to trial witnesses say he\n'],
#  ['four uk troops and officials are working to return the job despite joint operation contractor\n'],
#  ['state department has biden doesnt have to be a factor in every of is\n'],
#  ['the bodies and remains were found in a skeleton levee remain eight months police say\n'],
#  ['mitt romney had told obama he reporters a attack on the white house before reportedly\n'],
#  ['he thinks factors are often applied to his startling point talk about wise i should be the epitome of\n'],
#  ['tony abbott pledges everyone on some way out of their personalities baker kids they have three moms before people\n'],
#  ['obama will reject a law to implement the affordable care act he says budget plan begin of\n'],
#  ['bowe bergdahl is still living in his probably god bless you one to live says he couldnt\n'],
#  ['strict laws may be ordered for a struggle with death row police say the of woman cant\n'],
#  ['americans are seven to have increased billion on individual workers changing the priority is funded by\n'],
#  ['john sutter when pope francis in common sense of encounter with his cabin used to endure influenced by\n'],
#  ['jim martin new benedict will god rest as the end of our series rights he says has\n'],
#  ['boko haram has killed many nigerians as fighters in nigeria violence against militants attacked the campaign to\n'],
#  ['new the york fire was near center of making a possible source says city\n'],
#  ['daniel albrecht is airlifted to hospital after a sickening accident at kitzbuehel supercombined world skiing champion was training for\n'],
#  ['a friend says only served time near religion doesnt even be actually david frum proposal would not solve\n'],
#  ['the evening in japan is expected to hit a environmental power official says\n'],
#  ['new girls credibility on the dance creator says she and i have been married are\n'],
#  ['residents of moroccan capital have been evacuated in the capitals known as site africa\n'],
#  ['a woman shes wrestling with sarah palins husband using pair of performers she has just finished her\n'],
#  ['hiphop cup destination show for screening day clothing of travel blogger jim buckmaster is the lone ranger\n'],
#  ['the quake was responding to waves of a deadly earthquake according man who died sunday in\n'],
#  ['the report says legislation will be reversed but ability to say would end law\n'],
#  ['national obama urges congress to finish the web message on americans connect him public team officials say\n'],
#  ['hong kong protest leader denies its trying to persuade illegal go forward daniel treisman says the town is\n'],
#  ['bronze ball factory confiscated at the city of southern town swiss mayor trade center is under pressure on bus\n'],
#  ['bollywood and producer filmmaker dale jacobs his new entertainment is an exclusive interview with animated movie\n'],
#  ['james carville the murders in his library were held texas someone who had great information\n'],
#  ['the change may have been\n'],
#  ['new amnesty international says islamist will try to declare central african republic humanitarian leaders set up in\n'],
#  ['the ipad and features both android will also try to block consumer control seventh date\n'],
#  ['the taliban says plane has been scheduled to resume monday morning rescue crews have digging out of\n'],
#  ['sierra leone had been on floridas palace of progress has canceled hannah carter and arsenal\n'],
#  ['new we need to go on the situation says thats not set at continuing step over day of\n'],
#  ['entertainment became a unlikely to come new hunger gamesinspired industry youtube within the program\n'],
#  ['joined other miners left south as interim official bills join prospect of trip to florida\n'],
#  ['the emir says country is a longer place on sunday with change in political history former president\n'],
#  ['amazon southern middle east developed world more affordable housing authors body of millions will be\n'],
#  ['two of the top apple record in middle east club to chinas next\n'],
#  ['tibetans were told to use chant in the jail tibet slaughter of tibetan immigrants rights groups say\n'],
#  ['robert wright speaks at we were waiting for a swift changes to hardhit michigan mother says of three\n'],
#  ['amy winehouses death an claims it suffered from pneumonia tail investigator says will have his own blood recovered\n'],
#  ['tiffany tag a person on tv film feed of man who took check and\n'],
#  ['epa report gulf spill cleanup case is threatening cases of oil drilling threatens bp oklahoma\n'],
#  ['terrorist group claimed imam captured case will be used out court documents say us military says\n'],
#  ['honduras arrested over possible criminal arrest jose manuel zelaya is ongoing for being closely official gesture of\n'],
#  ['a fan ranges from social jay z to play documentary he says it will show and\n'],
#  ['some large hope travel on ice and exotic dogs where many are still hot inside western communities thousands of\n'],
#  ['saturdays match between start of interfering with bad weather to flight he says investigators made significant ownership task\n'],
#  ['germanys first principal dancer became lady in box office films seem to be difficult for most seriously\n'],
#  ['in obamas us holiday is to be a presidents struggle new obama and ed huang are preparing\n'],
#  ['joey long wins pair of brothers birthday dogs were featured on ice in the triple murdersuicide\n'],
#  ['the african company announces funding for children to sleep learn medical classes and access designer spent five\n'],
#  ['philadelphia soccer team hit for sixth season prior to third time this later tweets\n'],
#  ['widow says the family is expected to be released in a world no died united states since\n'],
#  ['new judge denies he is accused in connection with his departure court affidavit says\n'],
#  ['most americans living in the sleep and their prices are per cent off costs for\n'],
#  ['ed york ferguson spanish and new are finally a physician says olympics spokeswoman for william\n'],
#  ['tuesday is the hottest week in its opening been postponed a shift from by drama of\n'],
#  ['new itunes staff will meet on television next week monday the show experiment with radar and\n'],
#  ['gov rick perry and chris christie have worked on the democratic governors signature will be\n'],
#  ['new gop lawmaker says he cant bring up to solving his criticism from state news program\n'],
#  ['congressman says he is sending students to work with on the job some are protesters\n'],
#  ['july is producer says his death was behind it found in the prison\n'],
#  ['new tennis lawyer richard quest says it is a very scary time david cameron arrested in canada where\n'],
#  ['official considering sending personnel in airstrikes against troops combat spokesman says gen david beckham not\n'],
#  ['security officials say town of scientology efforts vow to stay armed at the area where gunman\n'],
#  ['google has always wondered why much of its time to this biggest talk and reality\n'],
#  ['rumors had before a new social media game he says the site was an online allowing it\n'],
#  ['more than million mammograms performed annually in the us be screened at same place every year makes comparing\n'],
#  ['the ftc says health care reform will be available on clinics behind cdc report\n'],
#  ['university of virginia was banned for racist chant the atlanta georgia no longer have\n'],
#  ['nearly of homes and customs officials are presented in new book the latest demonstration will help police nonprofit\n'],
#  ['near park and documents will end up to visitors through its very scale the location of\n'],
#  ['ryan brunn tells american idol for asylum in mind she has no time to be completed\n'],
#  ['the duck deflated sanctions at am paid it will be held estimated of full footballs\n'],
#  ['a second attack targets foreign aircraft to defend itself the an occurs in nigeria at\n'],
#  ['protesters marched on thai military seat as protest without some officials say they arent deployed many foreigners\n'],
#  ['this page includes the show transcript use to help students with reading comprehension and vocabulary at\n'],
#  ['frida ghitis arnold palmer walked off the program designed to build yours over old bright\n'],
#  ['campaign chairman says sarah palin told his candidacy during trail social media to\n'],
#  ['officials say there are no names to be shown properly fit nation says reason\n'],
#  ['body of the is found in name child alive a\n'],
#  ['cbs long been times since march dozens of followers it will take over the most contested presidential nominees\n'],
#  ['ruben navarrette says dallas international will be resolved to hit gm jobs also use cars tires for and technology\n'],
#  ['imf has challenging the walking because of this anxiety actress wants tv series what would be\n'],
#  ['gabors new year of the executive will make a back friday auction agency explain their own\n'],
#  ['deportation is the time of immigrants who aunt american law arrested state states\n'],
#  ['ibm images of thoughts about why whose global warming arent spoken in the worlds financial crisis japan\n'],
#  ['mobile car has grown from since to grow the tradition train around world\n'],
#  ['the company is working with a cartoon more than halloween jackolantern october youtube and are trying\n'],
#  ['caroline wozniacki facing case of princess tale but low as much teenage queen elizabeth seeks to profit from\n'],
#  ['hong kong chinese official says the jeremy lin is gay man working out of\n'],
#  ['the gay premier league club current football association with economic downturn\n'],
#  ['us marine cpl robert jordan most videos show photos of alleged orders to try see the murder state\n'],
#  ['charles and nick sullivan married team founder says he hopes to allow a peaceful victory expert took over\n'],
#  ['two children are involved in a week involving girl who may have job is model of\n'],
#  ['new fire at acres is having in a shipping resort the area one of officials are\n'],
#  ['president obama visited britain for january follows a to meet with obamas decision run\n'],
#  ['indian batsman thrilled andy murray lost his first innings on the brink of connecticut by wells and\n'],
#  ['two australian medics facebook page appears to show cdc employees need for serious issues so far in the way\n'],
#  ['barry manilow will be the first catching full film of les mis챕rables harry features a classic character and tv\n'],
#  ['resident of hardhit is a guided us and living in the middle east russian army corps are trying to\n'],
#  ['facebook is under a way to open contentious conversation with senators bills theyre appalled by sex\n'],
#  ['new french president francois hollande met and france for rescued says has\n'],
#  ['cpl joshua shouts of marine jacob bruce jenner medical patients left in california center hospital says couple\n'],
#  ['army wife slain woman charged with targeting womens tools and restraint continuing investigation into was shot\n'],
#  ['kimberly investigation is based on a sex education captive girls school says teacher trained at\n'],
#  ['the tourism cruise are being made in two cities like illegally living with its citizens right to explore\n'],
#  ['new greek lawmakers say the proposed aimed at protesters official calls for a fire says vote to\n'],
#  ['new lawyer says there is not been revenge for defendants say this europes investigation workers wikileaks founder\n'],
#  ['people have been fighting in the middle east isis could rise government switched to or syrias largest militant\n'],
#  ['if you are your way to see forget things like me from writes cnns richard perry says the\n'],
#  ['google and have nuclear ability to appoint a spectacular the second speed record previous\n'],
#  ['kevin hart made his debut on a manhattan ad before the second time drew back\n'],
#  ['the bomb attack is a major step near center of war making parts threat\n'],
#  ['edith windsor becomes part of cameroon player who has won three teams races due to breaking bad guys the\n'],
#  ['greek government is hoping to return a shutdown protesters said they will shut down sunday plans\n'],
#  ['defending horse racing lobby in london ahead of public park located a friendly which aims to\n'],
#  ['further tests showed no evidence in the cambodian nrc chief of chemical weapons company says spill was\n'],
#  ['a committee will challenge immediately members in the senate on tuesday ruling follows iowa is\n'],
#  ['the first of chinese designers must be born in china for a new album cruise ships story russians\n'],
#  ['serbian and novak djokovic first two points of monte carlo masters final murray nadal to extend history\n'],
#  ['prime minister presidential election conference in eastern president is assassinated new barack obama says he wants to show\n'],
#  ['new fred winters died becoming a bridge before baby official says of his injuries and newborn\n'],
#  ['new hes not a legendary royal princess from queen elizabeth ii william is at the age of he and\n'],
#  ['have many why survived in benghazi attack is one of its hotel peter bergen the first time to\n'],
#  ['new the obamas line of history is crisis encourages analysts are focusing on west area region\n'],
#  ['you can buy fuel and cover fast album yet spice up over tv even some dollars trying to\n'],
#  ['the israeli nuclear power is to be a equivalent of up victims holocaust titanic ii\n'],
#  ['totobiegosode tribe is among last uncontacted indians in south america ruling revokes permit for brazilian company to clear forest\n'],
#  ['a car finds in worlds central hotel rooms home by barry david german tourists are the subject for\n'],
#  ['china territorial disputes google world trade center to global net food industry patel wants provide environmental assistance\n'],
#  ['the aclu might not be deployed in zone even above agency says site is already under alerts related\n'],
#  ['new the suspect says situation is condemns a security official forces are taking over\n'],
#  ['new arizonas law enforcement official other protesters saying theyre appalled with immigration arizona says could\n'],
#  ['thai bahrain had sworn in as prime minister full presidential candidates continue to discuss persecution of others\n'],
#  ['cnn readers have key tools and answers with our feel writes david frum says the result of thing we\n'],
#  ['new chris taylor is on the streets of worlds most popular arrests official says hes set to crack\n'],
#  ['netherlands beat burkina faso in final draw both parties angola defeated czech republic meet\n'],
#  ['clashes over funding funds for months in due to normal campus police say program of largest ever\n'],
#  ['i have a photo of man gaining popularity on friday the new york times was an app store for\n'],
#  ['alastair peter global hunt renews a oneday test name england defeat mumbai in australia dhoni could lead\n'],
#  ['kurdish peshmerga forces have seized troops from isis to battle area border town of iraqi crossing\n'],
#  ['dutch stars french and son dont have a delight for go good morning they do everything in\n'],
#  ['womens rights watch across south korea are due to tougher penalties she says shes law on\n'],
#  ['supreme court justices were convicted of years in virginia on the home woman appealed to\n'],
#  ['at least rebels in syria strike clashes between opposition says ceasefire misrata does not sanction\n'],
#  ['club meeting with a music game of fame airport is designed to fight harassment occurs outside the mall chant\n'],
#  ['rafael nadal says he is ancient with a century europes sport which in history following the battle\n'],
#  ['if all runners will stand witness in or like police say amount of weapons limo\n'],
#  ['family has had a health update for the blood contains from midwest listed coral areas can be\n'],
#  ['new pope benedict xvi says the has been just elected to old university on moon mission\n'],
#  ['new there are still fighting between the us home officials say al qaeda suspects for all benghazi attack over\n'],
#  ['the decision in chelsea sign date end of english premier league vatican says vote\n'],
#  ['former washington state department has a good relationship in the us gop sen julian zelizer says\n'],
#  ['the case involves closing sunday an grand jury decision comes amid a deadly turn of confidence in yemen\n'],
#  ['the retail industry is made up a parody experience of investment in hotel few firms are\n'],
#  ['muslim leaders and military rule will return to port new constitution would extend supreme court ruling on countrys independence\n'],
#  ['causing evidence to warned us actions against holding off ukraine crew agency says no word was banned from passenger\n'],
#  ['tech conference was founded by apple and a new study finds it is focusing on the site of\n'],
#  ['new yemeni officials say they are not offering to establish a number of people the us embassy in central\n'],
#  ['brazilian crown mikaela shiffrin stars opened up a year after having guests in sochi winter olympics the most of\n'],
#  ['nfl commissioner roger goodell would give fans super bowl it was watched to an episode of the signature\n'],
#  ['everybody proud african union ad against africanamericans in schools march group says president does not have to be\n'],
#  ['keys became a way of rap crew on the hospital his son says father was veteran\n'],
#  ['the couple has studios are band of worldwide is chosen to make debut for tlc\n'],
#  ['bayern munich midfielder victor wraps up his second crash the president has stunned statue of\n'],
#  ['red bull cliff is set to live on off speeds await world series hit capt pauls\n'],
#  ['up to people may be displaced red cross official says government begins massive relief operations following deadly flooding more\n'],
#  ['the fire hits at center and down to red cross mayor are defending three children opened\n'],
#  ['new all possible wildfires have been contained a raging fire official says two identified as by\n'],
#  ['new i even that would be desperate expect me if you cant able to see\n'],
#  ['mobile tours titles are now tops the latest goal of stores starting with playstation features games\n'],
#  ['daniel hauser started second round of chemotherapy after new orleans in woes and left him depressed at\n'],
# ...
#  ['in new movie zombieland and the comedy through physical inactivity mel gibson actor\n'],
#  ['two mass attack in peru that killed terrorists the crash people who are a near\n'],
#  ['protesters seek up to school where gunman killed students at gun dozens have been children celebrate elementary\n'],
#  ['netflix became the most popular reviews of walking and dead in web series\n'],
#  ['militants are deployed to a baghdad area six people wounded in iraq\n'],
#  ['a total number of nearly million people have been spent on the property heavy rain this month will rise\n'],
#  ['sean moscow has been many powerful people in olympics but she became stronger brand as the way\n'],
#  ['thai military tried to seize refueling a hostage package she stayed in the right of holding\n'],
#  ['a senior us immigrant and worked in lebanon to sue him he had faced aid for her account\n'],
#  ['venezuelan president cristina fernandez heads the port of two states victory was both as\n'],
#  ['manchester city beat blackburn rovers lose to second strike has taken over england in and the\n'],
#  ['new at least rock n american rallies in syria tells cnn considering transporting a major force\n'],
#  ['chinese activist chen is released from incident by his was taken into custody in involving\n'],
#  ['former officer who worked principal by the story of her departure from abc news second woman and other\n'],
#  ['wendy represents often seems willing to believe what he says its too much be skeptical about\n'],
#  ['disney classic star kylie efron made a tour to the royal age actress takes journey\n'],
#  ['new one woman who saw her plane lost just before engine down from a wheel well\n'],
#  ['an airline says it is a test flight to launch will take net in and\n'],
#  ['solar power system is the first and engineer nations auto factories run road notes have\n'],
#  ['new gates says it is too long when gay law would protect changes\n'],
#  ['blake shelton wins four members of the taylor bride years ago she made her winners from\n'],
#  ['theresa county sought to nearly million copies in afghanistan samantha accepted a chance for photos of her supporters not\n'],
#  ['attorney says wellknown paleontologist will plead not guilty of stealing dinosaur bones nate murphy the judith river\n'],
#  ['lebron james said he was well after early his return to cleveland overcame fear of getting less in\n'],
#  ['democrats raised to run for president jeff carson says americans argue that electoral votes count republican candidates\n'],
#  ['generation of the sexual slavery include plastic surgeon leonard is first using\n'],
#  ['turkeys president francois hollande says bashar alassad is threatening government critics say syrias not the\n'],
#  ['a singapore forward lee kuan yew was prime minister had been run on public with personal address\n'],
#  ['afghanistans al qaeda if a military air force is out through defense federal\n'],
#  ['robert was convicted in the us army corps of public troops iraq no one shot\n'],
#  ['instagram is the internet users in while posts facebook and on\n'],
#  ['a long world cup of the nations store was inspired by queen jazz residents say\n'],
#  ['a cruise ship fire in mexico is evacuated on the gulf coast official says\n'],
#  ['new oregon lt dakota state dc mayor says group is ready for its safety an officer worked\n'],
#  ['south african president lee myungbak been buried in the wake of his lives north carolinas erupted he has\n'],
#  ['students from bus buses to seat or even at school guidelines groups such are trying become public\n'],
#  ['bureau of prisons postal service and other agencies get free katrina goods fema spokesman giveaway is not news agency\n'],
#  ['japanese court spoke at the first time since february dolphin safety group says we are deeply disappointed and also\n'],
#  ['eva big friend has gone the french footballer belounis near german was nearly seven miles in\n'],
#  ['nearly all kids homeless children still have been hunger from report stories include in the attempt\n'],
#  ['manchester city beat obama at home to win over st peters as extraordinary victory moves england standing matt\n'],
#  ['fliers went to austin near vietnam operating system site of computers are crucial recession researcher says has\n'],
#  ['police in fact say everywhere you face longterm aspirations or others the officer did\n'],
#  ['security officials decline to make tourists volunteers will stay at hospital or training the blast took place near\n'],
#  ['underdog wigan owner arsene wenger has expressed his economic growth he says manchester city are no one european club\n'],
#  ['national christmas day plunged into the mountains of africa three nations most provide average american airlines and\n'],
#  ['nigerian tsunami boat hits off florida coast of hungary aid agency says that was not the meaning\n'],
#  ['armed metal actor leaving his home in return to club while he was brazen and punished the cops\n'],
#  ['a federal user search at london is believed to be safer than project the device will funded\n'],
#  ['italy and greek fail a year after soccer fans forced the brazilian fiscal cliff of germany over\n'],
#  ['new david gergen says she and his plans to work with ground cnn defends the situation stop\n'],
#  ['the authors tale of lyndon is killed karen earl was on eve colorado legislature\n'],
#  ['manchester united crowned in group b juan carlos tevez seal a win epl by city\n'],
#  ['apparently online poker tshirts facebook more than people crossing eminem says are using the fire\n'],
#  ['recycling as a movement years old more than million tons of material japanese is celebrated much\n'],
#  ['former reporter this is a prisoner unit in china government champion muhammad yunus founder of studying\n'],
#  ['jason aldean riding high with new hit shes country georgia native conscious of ticket prices soap singer takes divorce\n'],
#  ['female staff members have said it was a backlash in the fort scheme she says boko haram kills students\n'],
#  ['mate learned of the continents mine belongs to jessica cash in prize money is transferred a year\n'],
#  ['a record hours in texas town is now under way to log cabin for power plant earlier\n'],
#  ['genarlow wilson accepting plea deal would have left him without a home promises to be more conservative alert\n'],
#  ['the national department of government airlines made letter from to debt authors say online was\n'],
#  ['over homes in istanbul turkey and condemn the city of jos garrett was suddenly size\n'],
#  ['the accused of alleged illegal immigrants under streets judges attorneys say charge may be when\n'],
#  ['islamist group alshabaab has claimed responsibility for the attacks it been targeted by boko haram one of\n'],
#  ['four us drone strikes were killed in a minutes after attacks on suspected pakistan\n'],
#  ['professor says japanese law will face charges in an incident of peter bethune he was white bishop\n'],
#  ['some of her daughter says there are people not part the emotionally draining time she athletes\n'],
#  ['refugee crisis south sudan camp in africa refugees resisted ceasefire march southern darfur region\n'],
#  ['david rothkopf talks with cnns broadcast on twitter friday to world hillary clinton is still in good\n'],
#  ['phoenix republican leaders say theyre changing the physically teachers every year they insurance now even more\n'],
#  ['apparently this week jarrett bellini is suing the of on tuesday day massive protests are\n'],
#  ['on twitter south african recipient tells cnn that killed was told intelligence assistance used to investigate\n'],
#  ['new revolution we hope a big win is now very one ever the best goal rock\n'],
#  ['authorities are reaching too red hook girl we have nothing to do without saving cross says people\n'],
#  ['jason mraz recently honored with songwriters award im yours artist amazed at where music has brought him intimidated\n'],
#  ['secretary of state kerry must wait hours disputes by islamic robert gibbs says the us should\n'],
#  ['nearly one of worlds biggest wedding is expecting a big against royal boys having heart attack the\n'],
#  ['crowds line streets for telling people in toronto after bear prime minister cameron comes on suspicion of\n'],
#  ['lapd often broken suspect guns in a joint attack was issued by an unidentified man who allegedly had international\n'],
#  ['former mayor of corps announces new research on current funding executive nominees\n'],
#  ['malala yousafzai will the girls school in pakistan to next britain has first education\n'],
#  ['a wisconsin child passed complete popularity on christmas day the couple took my family during theory\n'],
#  ['throughout europe expert says parents of young people are suffering from posttraumatic stress disorder core mental health dr\n'],
#  ['noted of the top gop wife claimed as presidents big voters do their relationship with what others have\n'],
#  ['china has pulled out of carbon monoxide in factories that have arrived hong kong the grand canyon\n'],
#  ['cheng says chinese authorities have stepped up a jihad behind the attack by japanese teen he was killed\n'],
#  ['russian tourists through international space station as a sailing speed record year ago gold helps\n'],
#  ['im sensing some matt damon and testifies mike carson told judge rachel jeantel is on trial for jury in\n'],
#  ['new the man allegedly sought to charge sheriff says tyler clementi jumped overnight on weapon he took\n'],
#  ['north korea acknowledges persecution of earthquake families back to south thailand and say the\n'],
#  ['children in syria a campaign to help trapped away wartorn northern iraq is becoming\n'],
#  ['new at least people have died in clashes the southern town of\n'],
#  ['the first men were found in a remote aircraft dong route california pleaded not guilty last week\n'],
#  ['prime minister tony abbott good questions are uk and bailout the remaining dollars will be affected by odds\n'],
#  ['new years ago that the same way was own ceremony she adds weve made it in\n'],
#  ['world war is one of the worlds biggest virtual champion developed modern and argues its software to\n'],
#  ['surge in poll revealed foreign citizens are angry over syrian economy they say first hostage of electronic abuse\n'],
#  ['new president barack obama will meet with international committee official says summit is part of a series americas\n'],
#  ['huge horse racing is a big mistake for cofounded by sunday worlds has had one of the largest\n'],
#  ['hundreds of photos catholics wait until this week the museum will probably be used by lebanese group\n'],
#  ['the presidents administration was told how that problems did children president defends perfect ideas for everyone white house secretary\n'],
#  ['jay parini his halloween controversy came up to a week ago gunman had worked out of the start\n'],
#  ['preliminary report found on radar equipment during a review of the crash investigators have criticized safety rules are needed\n'],
#  ['new we need fight info on the us border crossing a message of his fellow inmate says he saw\n'],
#  ['south korea is a reminder that make you on the way it said rejects away with\n'],
#  ['the gunman named william and son of afghanistans arlington national dialogue front he liam neeson grandson\n'],
#  ['several thousands of homeless children are here to meet in border the president says it offers\n'],
#  ['case from kirkuk african republic decide on countrys civil war crime body cases us government says end to\n'],
#  ['houthi authorities say yemen has no al qaeda group arrested by us some saudis were\n'],
#  ['bullock is directed to take an annual wimbledon race become awards olympic and gold but moved\n'],
#  ['spanish club wins on barcelona to and athletic bilbao defending champion must stay away at home\n'],
#  ['howard johnson there are creative success with big hits and go missing on his career bieber gave him coming\n'],
#  ['football fans were made by golfs world rankings show matches in series the has provided footage of\n'],
#  ['new state media say the detained has in us bureau man been\n'],
#  ['twotime indy winner was honored october to a flood defenses golf courses july businessman richard plans raise money\n'],
#  ['some people dont deny it in the lunar surface took place amid proposed websites of daily\n'],
#  ['virginia police say jared lee was arrested in his wifes gun around sexual assault he and\n'],
#  ['white house ag gen eric holder says hell take action on september he will part in after\n'],
#  ['the daily transcript is a written version of each days cnn student news program use this to help\n'],
#  ['richard iiis bodies will always be provided to his soldiers father says mother diana he saw the\n'],
#  ['south african nation to hold suspects with improper crisis countrys central bank police say preliminary information whether organized crime\n'],
#  ['some other countries and the are calling for a new policy on social media ios combined wealth\n'],
#  ['people have iphone out of the service around in some expected total beam\n'],
#  ['minnesota coach ryan fisher to be awarded the games at game of danny cevallos its not on\n'],
#  ['time we have celebrated its color for years of authority issue is a difference between our national security situation\n'],
#  ['san antonio mayor says ruben navarrette jr pushed his nonprofit message took place at home by\n'],
#  ['cnn executive thomas trained behind low health program speaker of street starting work hours working with family\n'],
#  ['frances economy is helping people in eurozone also the some\n'],
#  ['the kansas tornado has hit a major hurricane group in colorado national weather service says events it\n'],
#  ['police identifies believed guilty raises money that found fifth body public health officials say its not\n'],
#  ['sen lindsey graham defeated democratic candidates if congress would be no longer democrats want we\n'],
#  ['charles attempted visit trafficking militants in australia and many have been spent on the westgate age course leading\n'],
#  ['son of his family says admits shed like a month paris and desert the filmmaker will undergo impact\n'],
#  ['eric and staff were removed from political turmoil the protests have been used to hand over a religious\n'],
#  ['new england patriots in critical condition officials say pennsylvania for tuesday rain maryland is\n'],
#  ['new no lifethreatening injuries reported in or a denver area violent nature can feed\n'],
#  ['some in countries have been at the top of worst zone\n'],
#  ['the daily transcript is a written version of each days cnn student news program use this to help\n'],
#  ['new law passed bill would legalize gay marriage the away from to\n'],
#  ['british chef is a living with good employees to perform body language tics africa can make sure absorb\n'],
#  ['the mother of twitter is expecting best couple kanye west korean says singer has been in contact\n'],
#  ['boko haram has killed its militants in attack joint base combat operations\n'],
#  ['israel had trouble with a gerges zainab movements in the importance of holocaust gives it to create\n'],
#  ['sgt bret shoots his wife on a hearing saturday night in january staff had never it plans\n'],
#  ['the judge denies charges against him over a murder case is expected to sell million and granted\n'],
#  ['wifi is being used in time to attack security measures they will also be able use an app\n'],
#  ['anderson smith aka sam adams is on her new line of story out career peggy drexler\n'],
#  ['four weeks ago pakistans prime minister says no diplomatic and didnt ask trial to stay sense at the\n'],
#  ['amendment paves way for powersharing deal after violence disturbed election president robert mugabe mdc leader morgan tsvangirai signed\n'],
#  ['student tells abused for being diagnosed with rescue teams her conservator neymar named chosen\n'],
#  ['new burst out crane used to make light of flames outside paris airport station incident follows lightning\n'],
#  ['jack bauer someone to become president of ones in labor camps his wife is done about the\n'],
#  ...]

# %%
yourResult1
# Out:
# [['nina dos santos sat down from fathers day after vanished my eyes she says australian pms daughter can\n'],
#  ['lawyer says blogger who wants to make sure no the justice and time as cnns max manning asks\n'],
#  ['the peoples capital of <unk> was chosen as host storm tablets and receive youtube hours during september mall\n'],
#  ['poll percent of americans voters were nearly twothirds obama one women\n'],
#  ['new qantas calls on checks for hours of labor resume at least flights were canceled the airport ahead\n'],
#  ['ghana misses from south africa to rugby union regional cup the african nations now host are\n'],
#  ['halle berry has gone the star in hiphop world country band is looking forward to kid\n'],
#  ['general motors residents are beefing up efforts to rise violence during the crisis of global downturn president juan says\n'],
#  ['a new book to create an increasingly map of popular gadgets highlights plight failure and intelligence advice olympics\n'],
#  ['egyptian vice president hosni mubarak is just considering a year of egypts revolution egypt foreign ministry\n'],
#  ['jason aldean and eric hill got stuck from las vegas at pounds i wanted to have a chance\n'],
#  ['runoff race of former world war ii pushing for tougher poet election political rights was\n'],
#  ['stephanie jones gave great accountability board shortly before turning rapid change he sought at lack of poor dimensions is\n'],
#  ['david moyes manager sees demolition as robin cup victory cuts top of easy\n'],
#  ['the kentucky derby is set up for first time in january cocktail book follows vermont each\n'],
#  ['newt gingrich says most fear of his political win immigration reform he signs that gop is on conservative\n'],
#  ['james murray ran his advice after controversial moves from president obama had a close peace he says the leader\n'],
#  ['ed husain was sentenced to more than years in prison he had been six\n'],
#  ['bill clinton led a historian that hell koch and other family members who include some of his\n'],
#  ['new i couldnt get into the air police chief tells reporters nigella lawson was accused of trying to rob\n'],
#  ['indian doctors successfully remove rod from threeyearold child mehul kumar impaled himself while playing on terrace at grandparents house\n'],
#  ['new birth group is first named in giant diamond final girl taken to crown panda got\n'],
#  ['once considered the most famous painting walked in a new record based on number of more than years\n'],
#  ['the quake was centered near a sea center strikes japan emergency officials say miles east\n'],
#  ['new education the international government votes on a more vaccine case it took up some people die in sex\n'],
#  ['joseph fuller made his birthday with no longer sharing youth leader in which eye school generates electricity\n'],
#  ['throughout winter olympics take place in indianapolis for best drivers run formula one race sao tyler sports\n'],
#  ['a federal judge loses pounds in tree for five people an operation boise local authorities take to\n'],
#  ['unusual chinese hotels start in new york is complete the best business projects at charleston vermont and\n'],
#  ['officials say there is no political solution to bahrains security council one jihadist group reports that protesters were detained\n'],
#  ['dr earl bradley faces counts in which charged with rape charges stem impulse is leading to the ground officers\n'],
#  ['officials say but at least dead including weapons south and africa island town of those who hit\n'],
#  ['the flood victims will be raised by stress from many in past years ago girls are leading\n'],
#  ['the comedian is considered on way to marry stephen brady show one of worlds best scifi\n'],
#  ['<unk> ads using key tips is under use of teens computer sales a new drug dropped\n'],
#  ['rapper jack white and brad pitt had turned into music for years ago sound they say up\n'],
#  ['rafael nadal says straight questions about tomas berdych quarterfinals world no edges novak djokovic said he had percent\n'],
#  ['french force forces enable security exchange thwarted by colombia us military says ceasefire starting friday with kilometers per hour\n'],
#  ['tunisia mainly in city has its kind of measures to make way see people who are\n'],
#  ['six people killed and injured in pakistan security forces continue to give up islamabad\n'],
#  ['reputed opposition leader is one of the dead honduran teen who deposed president hassan rouhani collapse in state\n'],
#  ['maria sharapova plans to make the quarterfinals of tour wta in straight sets\n'],
#  ['chris christie and his family are out of a new year daughter says its become champion\n'],
#  ['new officials detain pedophile victims were among those arrested in italy laura kaufman pledges she was alone that\n'],
#  ['a written message that he was like used in the white andrew <unk> bush says and another\n'],
#  ['david gergen hates an republican atmosphere between gop race is in one presidential bid he says their way\n'],
#  ['will travel from new version of the future americas be released consumer electronics and technology\n'],
#  ['jacob cleveland accused of trying to get child served for the prosecutor says pleaded not guilty paralysis\n'],
#  ['new its not that right take a company to him with man controversial he says\n'],
#  ['gravity nominated scifi series in and established records films including james eric murray brian donovan theres\n'],
#  ['ed husain the internet is not a serious need to operate company on payments big new\n'],
#  ['da files case of july earlier this month follows last day investigation there were no evidence ap\n'],
#  ['vbs star tried to feel african people long from abroad age porn under of certain room older voices\n'],
#  ['corruption is officially added to the international monetary fund euro continent a economy for hour\n'],
#  ['in a russian club london domestic violence are held south china sea tourists to\n'],
#  ['lz granderson the mother of killed died in line and considered intervening with terrorists lives\n'],
#  ['the house proposal was scheduled to begin wednesday in hearing delay enforcement operation against senate floor\n'],
#  ['new teacher posed with the choreographer behind facebook reform at a hospital employee relationships through social media schools\n'],
#  ['mel gibson who had criticized lance armstrong on story she told was found daily with young men\n'],
#  ['new belgium gay marriage as samesex church group plans to\n'],
#  ['passengers ended up passenger plane airline flight was based on new jersey vessel carrying\n'],
#  ['the old city of middle east is most decorated buildings mascot\n'],
#  ['an faa spokesman in los angeles offered with drugs to break away elsewhere airport was precautionary while\n'],
#  ['new large number of items sent on a third the body versions official offer wanted directly to\n'],
#  ['we will meet with mark on thursday only one country has two other hopefuls and washington obama\n'],
#  ['ruben navarrette says the judge is million lawsuit alleges gross damages suit documents are\n'],
#  ['new four people have been killed in the bombings neighborhood one retired military seven others wounded\n'],
#  ['japanese architect has popularized sensitive traditions in buildings works across the world including museums and private residences\n'],
#  ['new barkley says hes disappointed in himself police were fantastic sobriety test revealed there was probable cause to\n'],
#  ['new thomas says his government is part of a shutdown paul green after vote statement\n'],
#  ['new its third birthday as one person died survivors at sea levels worst of people left on their homes\n'],
#  ['iranian foreign minister proposes a meeting with congress on friday many of the policy will focus\n'],
#  ['tai shan was born at the smithsonian national zoo birthday boy gets a special cake made of ice beets\n'],
#  ['timothy stanley how williams was hit by bands he says the conversation is dangerous she has\n'],
#  ['new more than large swath of south west carolina northeast areas high school in kansas city\n'],
#  ['the ship found in van and cuba to mexico pilot was carrying americans making it soon authorities\n'],
#  ['man held three black players with win over blacks less than four years ago going on to be the\n'],
#  ['williams says martin decided to have said we shouldnt their kind of cool nicole johnson that this\n'],
#  ['airbus unveiled a new replacement signal the cost of design work create\n'],
#  ['marion earl eric cantors negligence in louisiana riots was politically motivated and police her father citizens were sentenced\n'],
#  ['friend and jessica simpson are using a new film as an unusual twist critic of hollywood actors\n'],
#  ['quarter of the number cases died in meningitis due to swine flu measles was released\n'],
#  ['thomas gave involvement with murder agents he was arrested last week on vacation home agent says got\n'],
#  ['new the officer also known as of shooting hits police sunday night conrad reid said he\n'],
#  ['south africas high shortages of young athletes who failed to get social media action conference and experts if\n'],
#  ['a bill passed out by gay to adopt over samesex marriage ban on\n'],
#  ['jose mourinho says cristiano ronaldo linked to new spanish champions focused on real madrid rivals\n'],
#  ['jury in massachusetts case prompted by a contempt of the supreme court cases those used linked to\n'],
#  ['pat designed to address browns struggles with blood brain points she also said studies show that method could be\n'],
#  ['second seed maria sharapova said she beat serena williams in straight sets won a win slam\n'],
#  ['engineers at the african category flower city of cambridge tower system designed by guinness and largest call\n'],
#  ['sony stars much more than the andrew sopranos character actor was in late movie and family\n'],
#  ['this month fueled by kidnappings in the country year argentina a few hundred dollars are\n'],
#  ['many tv clubs appear to be former sen kirsten surprises gop feinstein wants mccarthy screen senate\n'],
#  ['increasingly seek to return kilometers due election kenyan authorities said most of its remaining were attends thursday or\n'],
#  ['new state threatens to stop charge of bill committee on friday lawmakers passed a that would get\n'],
#  ['the rb shanghai music has dropped consumer producer since its new star not just no hit\n'],
#  ['the aclu authority to decide that word of law banning statute it violates take\n'],
#  ['predatory mice are threatening the albatross population on a blue sea island native of st louis was abandoned by\n'],
#  ['british cyclist michael phelps wins mens world series skating he says will defend his olympic team from meters\n'],
#  ['rain caused severe flooding in late hostels a passenger says new his wife left wednesday night missing months\n'],
#  ['republic of monaco is worlds third largest economy in europe outside economic crisis current growing population\n'],
#  ['mitt romneys successful loss of the year was really terrible with your child who interviewed by\n'],
#  ['use the weekly newsquiz to test your knowledge of stories you saw on cnn student news write answers\n'],
#  ['at least killed in texas felt surprised by drone attacks on top of close weeks us supreme court\n'],
#  ['the man charged with conspiring to provide authorities seek alleged charges didnt prove wrongdoing in\n'],
#  ['naomi sims was one of first black supermodels on notable cover ladies home journal in many\n'],
#  ['arming nato secretary carter is considering review to defend foreign policy of state also says congress\n'],
#  ['spotify or live with a hometown of white adults making public people at home seat the\n'],
#  ['gloria borger says president mitt romney was involved in fighting with israeli force hes said he wanted to prove\n'],
#  ['new retail committee condemns attack on blue towns headquarters victim raises scrutiny capitol hill in\n'],
#  ['new no one expects to take advantage of an emergency toilet interest in request make sure\n'],
#  ['flight from brazil survivors say kids were forced to help prostitutes in portauprince dutch embassy says theyve learned they\n'],
#  ['new york gov david perry has to meet with <unk> but he is the former\n'],
#  ['rapper michelle obama at center of black community she says blues is the great culture five kids\n'],
#  ['most victims have found the law bans massage parlors and schools remains a murdersuicide chief district attorney\n'],
#  ['more than of americans are starting to live in african and united states connections can view up family members\n'],
#  ['tennessee teen started crying blood tears in may he suffers from rare condition within pounds of pill portions\n'],
#  ['the transport plane went down van as a normal second time drug charge prosecutor says flight follows\n'],
#  ['sen barack obama slams democrats to run for political action against gop will not win one\n'],
#  ['transportation secretary of new yorks remaining restaurants is on its way the house options wide switch also\n'],
#  ['capital threatens and construction progress on potential economic destruction in expanding the assess recovery project will explore\n'],
#  ['the daily transcript is a written version of each days cnn student news program use this to help\n'],
#  ['al qaeda group boko haram claim terrorist attack civilians tried by islamist syrias government leader\n'],
#  ['many troops were the withdrawal from military sent to iraq through iraqi boston\n'],
#  ['manny pacquiao takes home to the la liga on his debut monday fellow real madrid end score\n'],
#  ['howard kurtz is the second audience based on politicians and depicted <unk> of digital age\n'],
#  ['sevilla red tide rises with million at\n'],
#  ['two pirates crew members were found after the sewol arms three days ship chinese are\n'],
#  ['muslims have chosen as a us citizen on sunday many of the demonstrators say there is constitutional crackdown\n'],
#  ['cristiano ronaldo criticizes referee fails to complete a year injury he led capture his first flight from\n'],
#  ['we criticized up after a conference on internet companies users have been working virtual bus company\n'],
#  ['time of six wickets aim for a better chance seats to the end weekend jim bell\n'],
#  ['emma watson says we have a chance to define me on social media the singer has criticized act\n'],
#  ['marine was one of the biggest drivers in city october truck driver injured alabama last\n'],
#  ['more than wounded in the landslide up to million afghans say they were killed eastern afghanistan\n'],
#  ['portugal have regain to the worlds most complex options in brazil winger goals for a confederations cup glory\n'],
#  ['legend is now in the game of <unk> film made debut\n'],
#  ['russian spacecraft contingency contract puts hostage rescue of rocket launch in nigerias military base the nuclear watchdog\n'],
#  ['the earthquake making first deployment of nearly four years later there were no such practices training and\n'],
#  ['us district leaders on gay marriage just returned to parade by white house supporters of fallout group followed end\n'],
#  ['the great lake is best meal of eating hot springs index sees many in countrys vibrant\n'],
#  ['producer was hoping to raise money on the water he went same\n'],
#  ['syrias government plans to wake up fight mount between square protest refugees flee large areas near jordan\n'],
#  ['<unk> magazine has created a new form of technology in internet now by most influential he says\n'],
#  ['jeffrey toobin says court that law should have dont deserve to she would a\n'],
#  ['muslim brotherhood decries coup against al qaeda in supporters of led after bombing\n'],
#  ['maria sharapova has a focus of what she says they are looking at men who in paris bride\n'],
#  ['sentences for europes businesses and the protesters were on streets of crimea leftist city was\n'],
#  ['police officer nazi robbery shooting shown to switzerland after car bomb explodes outside suicide bombers\n'],
#  ['thousands of flights are canceled across the city washington is cutting economy to bring in\n'],
#  ['france considers resolution recognizing militants in hezbollah ukraines new ambassador lebanon peace process syrias growing\n'],
#  ['roy hodgson takes charge of english club champions with second dismissal after milan help arsenal manager later moved to\n'],
#  ['sophia is a good person with great friend his success of the season tennis star pat butler says\n'],
#  ['europe beat japan to seal their victory over in history st louis cardinals sergio perez defeats\n'],
#  ['students will investigate other girls maintain a new york city the groups also wanted to be\n'],
#  ['at least killed people new au group one person\n'],
#  ['the english premier league club will take over if chelsea move to beat in european history would reportedly\n'],
#  ['new im sorry that her family mourns says andrea nelson died last week as brother did\n'],
#  ['apple cofounder reveals developments in future of competitors march to announce news at event companys global\n'],
#  ['frenchman stephane peterhansel takes against monte carlo in his hometown el clasico he is a champion with\n'],
#  ['new monkey and mexico is way to all our lives really study finds that youre\n'],
#  ['kanye west opens up about his marriage as leno gets a mix of support for the dance and get\n'],
#  ['people died from fall injuries after continue to help victims in storms an estimated\n'],
#  ['iranian scientist says he has recorded the countrys nuclear particle is set at chinese erupts in\n'],
#  ['victor beijings high cigarette revolution now use the poor wide map behind beijing olympics app industry is\n'],
#  ['new manson is on trial she says was convicted in her parole after then released a hearing\n'],
#  ['expected to go ahead of the sochi games in winter event is designed achieve\n'],
#  ['bus teams get out of water as many doctors ordered drivers to remove all rubble hiding homes\n'],
#  ['eric liu organized a popular role of kids as they wanted to see think the attention is\n'],
#  ['arsenal manager arsene wenger reaching gap on his arm the west african president opposed for world no\n'],
#  ['new that he and his family give our lives in mississippi man defendants arent identified the actor\n'],
#  ['us man threatened while suing rulings on human rights youth matthew simpson and miller free to testify they were\n'],
#  ['a suspect in the sex case judge denies reports of neighbor\n'],
#  ['parents casey anthony was sent to email thursday her letters about emotional health program when\n'],
#  ['the rapid call for obama mcconnell wants to see economy some say democrats need well leno obamas push\n'],
#  ['nfl chiefs doctorate in thinking about sexual abuse allegations involve charitable lost parents fired the boys front and\n'],
#  ['mario balotelli was sentenced to years in prison for recent rights movement of justice presence\n'],
#  ['faa releases three flight attendants to airlines for nine months said decision was first dropped after of\n'],
#  ['community of inmates family members mansons ran in jail on parole after february house\n'],
#  ['new the court will hear oscar pistorius and his sentence has failed scheduled with that\n'],
#  ['mladic directing highest and ordered other cases at least people accused of criminal trespass were on\n'],
#  ['throughout years jews have been blamed for of public labor according to bc in russia blew the\n'],
#  ['a jersey legislator says he will travel up to transgender people without the city council on high court\n'],
#  ['israeli parliament is to irans nuclear and its cultural ties israel says iran watching the for sending\n'],
#  ['a judge is indicted after being as leading product boards fda obtained women to berry of\n'],
#  ['obama plans to weigh request of president iranian hamid dabashi says the will visit\n'],
#  ['wayne rooneys is in his shirt squad on sunday the manchester united boss will also reach football team\n'],
#  ['us national group says becomes first foreign policy against european union female man argues that should\n'],
#  ['an audience of popular king was shot dead in the las vegas hotel paris filled with chains\n'],
#  ['million haul from lander art confirms mubarak still found wanted in his honor books dies of being mysterious among\n'],
#  ['manchester city win at a draw with sergio aguero from behind victory over tevez scores winning\n'],
#  ['the us supreme court declines to appeal orders contacts face charges related those who threatened do\n'],
#  ['crystal wright says most of his sleep <unk> chances running made for mate alex the only\n'],
#  ['the parties werent very touched away with queen of word on hand party honors her deputies\n'],
#  ['david rothkopf it focused on his issues he calls to the words happy for proposal\n'],
#  ['tokyo music sales were peak in ocean giant bowl by zip line japan the cable features a song\n'],
#  ['man lands on the moon july with no one writings indicate he had doubts about appreciation attack house\n'],
#  ['like walmart man tried to find a in and at least four people have died his plane was\n'],
#  ['timothy stanley chickfila might be labeled as a danger to having food and goes free hot other\n'],
#  ['taylor swift had other issues in mark silver tweeted about the wall alcohol charlie gibson singer was an\n'],
#  ['germanys reputation of brad pitt is pope as a world his standards former champ has been beaten\n'],
#  ['new national guard troops deployment is expected to shrink decision at base in ivory coast included later linked\n'],
#  ['million people in the united states offer up to visitors but there is growing between and always great\n'],
#  ['the migrants cross coast of yemen in panama and nine other people home four\n'],
#  ['saudi arabia is on the verge of involvement in case state media say couple entered response to\n'],
#  ['japanese police have penned international ballet from tehran to honor student image roma never sending songs visual\n'],
#  ['search for air missing since plane involved ntsb says in and a\n'],
#  ['former players say he thinks people have assumed confessed to show his says hes considered too emotionally\n'],
#  ['official uk denounced poaching destroyed between ocean island has been investigated china and south korea\n'],
#  ['most wanted to walk away from the rubble of saturday night cnn pulls wave obesity is used\n'],
#  ['new mexico offer no immediate help claim it takes influx of injuries the groups say haiti does not\n'],
#  ['angela merkel leads ceremonies to mark earth day post berlin on top of them at local visit\n'],
#  ['photos of air military advisers will lead afghanistan in red cross official says the attraction is only one\n'],
#  ['a foundation aimed at people and un working to deliver huge number of is fallen in\n'],
#  ['mccain on netflix fox tv fights have now important to answer questions about president barack obama wednesday expect\n'],
#  ['belgian man held by uk media say the mother of two released early sunday killing a french family\n'],
#  ['michael jacksons dance moves his look were emulated jackson inspired artists such as usher justin timberlake and rapper snoop\n'],
#  ['a new york times bigger is posted on the page heir to cover evidence called\n'],
#  ['inside chinese art has helped shape the way on its key modern family can create a to find\n'],
#  ['recent dialogue can use robot electricity and products to create public spaces on the phrase may be from street\n'],
#  ['photographer this years eve of his christmas religion and blessed new he cant celebrate londons streets painting on\n'],
#  ['pope francis represents the worlds first living channel in he tomb world it approves two\n'],
#  ['jenni mother of the spanish teen is having a baby daughter in united states she alleged to\n'],
#  ['a judge says james holmes is in the district debra harris charged with felonies\n'],
#  ['liberty and scalia ran as a deputy writes he says supreme court rejects case against faces\n'],
#  ['david perry gives his sons estate as an avid action over relationship he says hes still thinking about a\n'],
#  ['meg urry gender of marriage is high as the record rate she didnt name anything after summer raping\n'],
#  ['two men in one of the separate things found say mother says nigeria his blasts\n'],
#  ['<unk> the number of silent animal beauty called belongings were got because they a culture get\n'],
#  ['mumbais taj mahal palace tower oberoitrident luxury hotels reopen both were targeted by gunmen in last months attacks\n'],
#  ['new family apologizes to excellent claims sunday\n'],
#  ['delta air traffic system has been involved with association of flight nearing doors room size protection officer says\n'],
#  ['the woman would give peace knowing about his sons plan explaining medical care for years raymond king george whose\n'],
#  ['new france appoints a manager paolo after manchester city announces he will join an executive guitar at the\n'],
#  ['democratic opposition leaders and committee must decide on veto of rights democracy council calls un for economic review\n'],
#  ['british tennis midfielder love up over spain and modern his rich crying i had injuries from the size\n'],
#  ['former senator teams will help another race they say this is a hell to answer police turn over\n'],
#  ['of eu travel european countries to be reviewed on sex trafficking and growing destination why must worth living\n'],
#  ['new state university sports south korean coach who has seen victim or tired of schools his is\n'],
#  ['boris zinedine zidane and fined for his loss to italy chris brown died in dui crash\n'],
#  ['white was released from an annual tradition award anniversary of dedication period chicago police release record\n'],
#  ['man has pleaded guilty to charges of aiding al qaeda bryant neal vinas interview with belgian prosecutors is released\n'],
#  ['peggy drexler parents leave are tied to a mother and tsa officer in plane went\n'],
#  ['companies from apples track company demand move to concerns over luggage of five tokyo shut down\n'],
#  ['analyst says most people have been said known story has changed fears in recent months\n'],
#  ['settlement units of systems failed their israeli government broker to move on construction since the east has been\n'],
#  ['woman found she received girls from her own baby husband in march was before\n'],
#  ['former court rules will cover case against carlos administrator in jail awaiting verdict indictment alleges hernandezs convictions probation\n'],
#  ['the blasts hit in pakistan officials say new taliban claims responsibility for explosives killed\n'],
#  ['the horse racing foundation has won science race medals to make up of in preparation ice\n'],
#  ['police praise alleged rape of a british press officer to arrest investigation into the allegations word by\n'],
#  ['luxembourgs spiritual leader bruce willis was destined for a statement after it had brief encounter with stroke\n'],
#  ['national mourning center on roof of blazes measures passed by all six afternoon damage damaged weather\n'],
#  ['spains euro arellano utd announces a beating manchester city two goals after ronaldo and zlatan ibrahimovic hits four million\n'],
#  ['ask twin brother of the real names are revealed as a new avengers series cyrus disney library demanded\n'],
#  ['obama and other parties agree on plan to close early hours sunday economic emotions impact\n'],
#  ['campaigns may have become pregnant actress newman gender equality for political violence she says found sexual\n'],
#  ['local zoo animal protection act in ireland intended for their lives services were founded the park\n'],
#  ['the greatest system of pacific is estimated to be million visitors will years ago economy\n'],
#  ['bus connection through region to continue for killing four people in world faces dangerous attacks madrid\n'],
#  ['reputed finance minister says he is not suspected of domestic terrorism according to forbes reliable independent drug cartels use\n'],
#  ['some of our most powerful party well start habits we are ending up to be successful so people win\n'],
#  ['the largest memorial service is first national parks dedicated to independence at top of annual tradition\n'],
#  ['the turtles have been overcrowded with crew off ship philippine coast guard says it is too\n'],
#  ['any billion airline will be made out in its dispute now rep john king says he wouldnt tell\n'],
#  ['professor says racial doubts the loss of syrian rape and possible crimes against sending our\n'],
#  ['russian forces have been killed in connection with the military officers believed it was target of national geographic\n'],
#  ['emily page seeking to protect southern mali group reports of a hospital in after working antarctica camps\n'],
#  ['marc marquez claims victory for his first moto gp the honda veteran is seeking second venezuelan\n'],
#  ['ted pact with chinas biggest tech industry is leaving the film digital age of year\n'],
#  ['years of the gop senators have their longterm benefits for country ashley montana lawrence cooper is spending generation\n'],
#  ['new there are no tsunami advisory declares three evacuations kyodo news agency says it is immediate reports of injuries\n'],
#  ['some believe the things arent on rise might consider observer disputes decide with scandal will\n'],
#  ['the people auctioned to claudia hunt for first months in federal auction letters were and said\n'],
#  ['bill clinton gets first family role in that lead to other on valentines day she never asked readers\n'],
#  ['new south africa included a draw against spain in connection with the return of abbott\n'],
#  ['ntsb is investigating some of the possible chance any evidence new case no longer if\n'],
#  ['new at least people return hospital says toll number is not doing back the camp up to\n'],
#  ['new hurricane controversy over million americans are not doing milk and longer worries some people without a risk\n'],
#  ['new us and china hit an unprecedented stronger bill breach in japan taiwan ahead of currency\n'],
#  ['former chinese diplomat says he will face criminal charges his remains in court was facing homicide on\n'],
#  ['new to step down theres been classified as a accuser says government\n'],
#  ['google launches a new version of its website for the app will be\n'],
#  ['new armys old coach says it will not allow her monitor models to pass them\n'],
#  ['new second shiite islamist militant group is killed in explosions outside of cities karbala police say one\n'],
#  ['the anniversary of attacker was opened against victims miguel player albert riera he also accused being\n'],
#  ['lz granderson says president spent budget proposal republicans have tried to bring back political companies van introduced democrats just\n'],
#  ['image of who criticized by president obama sen robert f kennedy report says is racist he\n'],
#  ['us government israeli targeted diplomats of militant say other countries order\n'],
#  ['cristiano ronaldo is named in madrid for a winning title new york beckham plays on twitter seven\n'],
#  ['florida game of pittsburgh beat big in rules trails opening\n'],
#  ['the first starts saturday and is one of tongue star defense secretary tells family he his\n'],
#  ['the march fires were completely less environmentally friendly city in more than square miles are\n'],
#  ['chelsea striker didier drogba discovers champions league with his rayo vallecano run christian bale in home match against juventus\n'],
#  ['note we seek the difference most of family loved ones was who registered single this love\n'],
#  ['specialneeds baseball league near atlanta has nearly children some players use a wheelchair but others are ambulatory field is\n'],
#  ['hundreds of protesters are killed and activists in egypt tunisia break egyptian military protests cairo authorities have\n'],
#  ['country faces a second of chinese leader from national workforce first president new top by fifth largest\n'],
#  ['new airline calls fuel blazes text messages and planned to occur immigration officials said obama ordered more than\n'],
#  ['british and officials say theyve found phillip isis in iraq the former army has now says paper\n'],
#  ['police allegations have a very search for any credible criminal charges say there is investigation this\n'],
#  ['susan smith years of the countrys democratic republic society naomi campbell brought odd key political slavery\n'],
#  ['sanjay gupta is the ruling of bali that was in response to middle east disaster\n'],
#  ['bob greene the new orleans is like your most diverse divorce he reiterates countrys travel industry has to\n'],
#  ['group wants to know if meeting of prince philip do name people will join the as part\n'],
#  ['student died after an unprovoked shooting in virginia campus university students alone they were at airport around\n'],
#  ['david wheeler financial supply is a key factor he says robert gates top military solution to\n'],
#  ['the top monetary bill and bidding breach of sweden financial loans national swiss\n'],
#  ['vidalia onion committee to place cutouts of shrek in grocery market democratic officials say its because good if\n'],
#  ['defense officials did not dim sum only in the province of lists confirm\n'],
#  ['michael jackson albums dominate bestseller charts on amazoncom itunes online retailer playcom reported album sales increased by percent\n'],
#  ['new planes are over in libya next month people expected to arrive saudi arabia and aviation authorities\n'],
#  ['the third quarter of worlds highest budget thing that wolverine opened a million but there are more\n'],
#  ['william bennett weiner as chicago mayor bob greene says much dallas snap\n'],
#  ['magic mike is an nba player in a videotaped sikh fight over the social network he says\n'],
#  ['the us air exposure is fence landing screeners department denied leak at request of a\n'],
#  ['president obama and biden have discussed recent events to speak about said sense of attending conference\n'],
#  ['family of georgia resident sees clues in response to a houston attempt by the sharks man found famous\n'],
#  ['british football match to international captain sail against japan the world cup is auction\n'],
#  ['a un official says people have died in detention period guinea liberia and sudan troops those who exposed\n'],
#  ['police won two years after sundays greek revolution historically man died while arson sunday at least four people\n'],
#  ['lasers that blind pirates are now available to wealthy superyacht owners the only temporarily impair eyesight and make\n'],
#  ['john kerry says air force astronauts still can get military aircraft supply crew members say he was trained by using\n'],
#  ['kevin parents were the youngest sister andrea died while he played billy wilson death taylor mother lead\n'],
#  ['the judge says osama bin laden was shot dead in gulf of mexico on a wedding border wiped\n'],
#  ['tehran was described as irans president of relationship between israel and palestinians says jonathan miller who\n'],
#  ['expect romance with a realtime game will determine if the lies should have to block their epic\n'],
#  ['death toll from the blast was killed in rubble of a police station happened monday on\n'],
#  ['a neighbor tells of civil rights commission the mother slain group claims case was\n'],
#  ['museum creates path congress to pay for seafood in government project monsoon jakarta dump million food spending\n'],
#  ['the singer is fatally shot himself and a homeless fan prince william child private officer dad straight\n'],
#  ['new some hotel express to take homes a chain of air <unk> says hundreds animal inaugurated at\n'],
#  ['new the japanese prime minister tells us does not pose a danger\n'],
#  ['billionaire dutch actor brad r obama to pay tribute love this day i celebrate the campaign for\n'],
#  ['bmw brothers hunt in one reality tv roles include players gun shops hall districts including african woman is\n'],
#  ['new the senate to pay billion for tax bill contest calls vote bid\n'],
#  ['michael vick wrote fivepage letter to nfl commissioner left more than rounds of career eight other players right\n'],
#  ['naacp unveils new program to allow people report alleged police misconduct texts emails can also be sent\n'],
#  ['mark hughes is dubbed the most powerful breakfast in guinness world economic forum new years hopeful that are\n'],
#  ['animals are experimenting with google glass and cans at sea forest air travelers say should be a provide for\n'],
#  ['new floyd mayweather has resigned advantage of his loss professional debut mark johnson who died in\n'],
#  ['larry edwards returns to affair with no apparent threat him next week has accused of accepting\n'],
#  ['the daily transcript is a written version of each days cnn student news program use this to help\n'],
#  ['<unk> friends are in the back of six them doha front one suspects chad\n'],
#  ['iaea on airstrikes leaked early by general assembly march irans nuclear program passed the senate review of\n'],
#  ['sebastian vettel will join team at new ninth brazilian replaced the mayors form fourtime world\n'],
#  ['social network users seem shared more than when it appears to be used help user photos the\n'],
#  ['beverly hills owner was filming a film based on tv show he found dead while\n'],
#  ['testimony given at preliminary hearing for models doctors lawyer pharmacist testifies exwife lied ill with depression so he also\n'],
#  ['the report shows why are mad world men believe spreading media coverage believes\n'],
#  ['the illegal satellite targeted a record of aleppo is syria says opposition group it will be\n'],
#  ['researchers uncover question of waters off the coast ocean arctic nearly a century indian\n'],
#  ['secretary of state to attend meeting with her sons second hiker luke gullberg was freed she will remain assigned\n'],
#  ['new investigation reveals nothing to the alleged crimes published in illegal slavery us is john\n'],
#  ['analyst says nato forces face war against ukraine possible un attention to attack those weapons\n'],
#  ['lionel richie likes father of his grandchild says nicole shouldnt rush marriage parents love and support\n'],
#  ['japan is a large protest off the south korea group called tour to meet this\n'],
#  ['official calls the ban on a second weapon of south waziristan an officer tells security ap report\n'],
#  ['south korean president says <unk> was extremely hostile flags a native queen elizabeth ii wearing the paint\n'],
#  ['american academy of dermatology tattoo regret common in the us current removal process is painful expensive timeconsuming new\n'],
#  ['video of man accused plotting to show his death police say six people were killed him spokeswoman says\n'],
#  ['ioc head to introduce payments for the olympics opening games worldwide russia needs world cup and field teams\n'],
#  ['nicolas maduro says power is in effect but it was the killing of israeli military since\n'],
#  ['cnns piers morgan robertson is the first woman who writes in a became she\n'],
#  ['new authorities have found the control of a drilling protection area in alaska government says coast guard will\n'],
#  ['some people have caused a voice in facebook and twitter are getting updates to social media\n'],
#  ['report says preliminary inquiry lists a during lawsuit against human trafficking alleges error\n'],
#  ['source says people found air staff in assets at airport traffic controllers note paris was\n'],
#  ['nobel foundation accuses tony islamic republic of humanity syrian president his group office in connection with the\n'],
#  ['more than have been released according to story about boy stories like jay z thriller starring robert russells ground\n'],
#  ['us rep daniel smith during microsofts job leaving airport summit part of contract workers on board budget cuts\n'],
#  ['new two suspects in phone each other police spending woman accused of friends after her first\n'],
#  ['david haye who should be tried to stop the word of\n'],
#  ['mars one of the worlds biggest sporting size is surfers huge cars are reaching out\n'],
#  ['demonstrators say more than people have died in a home protest cnn says there is no sign of\n'],
#  ['new its six systems spiked across syria at an area around damascus a large the syrian border\n'],
#  ['<unk> american is accused of plotting to force a federal judge in legal solitary and may another fraud\n'],
#  ['people have been told supporters of the morsy would killed osama bin laden i to\n'],
#  ['the cargo ship is safe japans countrys first japanese diplomat injured ships are cutting off travel\n'],
#  ['demonstrations across beirut news says syrias prime minister promises new peace plan went to a very dangerous period and\n'],
#  ['a fossilized valley of the kingdom fell almost any its diameter own forest park in northern nigeria\n'],
#  ['ben and connections personality take a focus landing in libya the film is part of chaos\n'],
#  ['group says blackwater have network where people killed and eight in clashes bombing of\n'],
#  ['consider fighting in the wake of political prisoners around world war dictator took effect prison for nearly\n'],
#  ['new johnson the first female killers interior officers are seen away over selfinflicted gunshot wound explosives cop campaigns including\n'],
#  ['illinois prison officials are selected as one of two men they accused killing their children say\n'],
#  ['a construction army seized in an inspection maiduguri police say soldiers were among the victims\n'],
#  ['chinas hopefuls top publishes new details on the moscow secretary of state john kerry and two more chinese leaders\n'],
#  ['joseph duncan committed suicide last month his father says he was sentenced to death august charged with murder\n'],
#  ['a fifth plane urges network of the united airlines flight data into relatively state\n'],
#  ['new the tornado destroys another person dies in damage was same area emergency officials say\n'],
#  ['a number of service students will be among those who have purchased good payments to signs problems\n'],
#  ['in the states chairman of passed second country united club says it will\n'],
#  ['new the actors says there is a booth call in scene of action she\n'],
#  ['roland martin says ted kennedys birthday reminds us of the media luther king jrs image shows fate\n'],
#  ['a tropical wave of special electronic electricity is investing in and destruction the us uae\n'],
#  ['police investigate arrest of fine students at a city school new give no details about the shooting\n'],
#  ['japan opens its new auction in november stories about monte carlo cars are used cyclists car and cheap\n'],
#  ['vietnam raid at over china in sparks rare annual arms war least million people died\n'],
#  ['us intelligence department of global agencies among potential ideas to security russian analysts say the united states\n'],
#  ['rugby play the young of world cup and beat rankings african nation\n'],
#  ['for many decades after years of political genocide has dropped annually\n'],
#  ['the allegations previously planned at important state department in syria german will be voted against libyan\n'],
#  ['more further orders out of a ton bringing him closer to those killed in the air on\n'],
#  ['number of us people killed in the rate americans who have been politicians say debates\n'],
#  ['new the passengers were on tour bus in aspen colorado police say no injuries was not unknown reports\n'],
#  ['its ability to die in the internet since once use of at headquarters\n'],
#  ['crystal island is an unlikely story of the house gloria borger asks why forest treating fresh interest in creatures\n'],
#  ['a judge sentences in the case that shed be classified hours of steven knox was\n'],
#  ['new royal fleet will go on network in joint air safety remains without identification this week collision spread\n'],
#  ['president paul ii is ruled out of the presidency his closest on race by mccartney for philip\n'],
#  ['new police officer says they have come through her own body another record for murder foul play includes show\n'],
#  ['frida ghitis president obama are being focused on good media and why they say she is a impact america\n'],
#  ['max rosenblum gets to take a buffett tour hold the door he says jett contracted carolina weapon\n'],
#  ['glenn wilson many role in modern family is different but the red star consider night show that one\n'],
#  ['the house passes employment policy as long it leaves american farmers insurance applies to failed\n'],
#  ['bergdahl in his wife allows him to travel into vice president joe biden mother is freed\n'],
#  ['no one case was denied abortion in the state media say killing of\n'],
#  ['ba lu channel of <unk> helps poor people donations to recession creating housing and performance should\n'],
#  ['bill gates change is largely peaceful experts say they will always be together with a whole to current marriage\n'],
#  ['filmmaker and author of new york studios rang the story on african tv apple is a film\n'],
#  ['boko haram blames abusive elements in their homes between nigerias syrian christian city the villages\n'],
#  ['new destroyed man formed in athens suburb of christian city known as he home religious center\n'],
#  ['daniel albrecht is airlifted to hospital after a sickening accident at kitzbuehel supercombined world skiing champion was training for\n'],
#  ['the obama administration is running after saying white house says super bowl will debate some republicans hesitant\n'],
#  ['many communities are evacuated but reach is not bigger than rain has come near a <unk> warning system\n'],
#  ['couple with up her boyfriend from husband argentine ace kids at age she had worth million in bed\n'],
#  ['football shows funded by african and poor in africa has had a fight for percent of the upcoming\n'],
#  ['leaders know that cant see battling in the aftermath polls cnn says want to ground lines\n'],
#  ['its passengers are in a passenger because of too important the seas past dave noticed stewart and others\n'],
#  ['a third strike found was killed on high tsunami caused by grim sleeper is dead batsman morgan died from\n'],
#  ['eric liu margaret deborah cornell accused of killing people in a mass shootings but not rule against nigerias actions\n'],
#  ['potential shift in the wake of country security and committees says washington is moving up opportunities challenges\n'],
#  ['student li na in hong kong was sentenced to years at main news conference he also had set\n'],
#  ['police say one man seen multiple nonprofit including a percent jump street fire the boat was carrying constant workers\n'],
#  ['artist clark showcases the ancient fashion designer julien macdonald on countrys beauty of luxury bands film internet freedom\n'],
#  ['in a television story john crawford iii biggest star identified very best the man lee said film\n'],
#  ['spate of mental gun and weapons weapon suspect women told police firearms\n'],
#  ['new clashes search for those who have fled argentina amnesty international says continue to stand trial this year\n'],
#  ['apple and samsung have not been released a double invention close to special brand of legal\n'],
#  ['robbers will not be between the countrys largest senior taliban spokesman says is only one of\n'],
#  ['passengers who took more aid in days before arriving tacloban after severe weather one town stranded african\n'],
#  ['leaders of the rebels want to know opposition on iraq a senior leader moammar gadhafi must change its\n'],
#  ['some chinese films are now one of the most difficult gathering film came with\n'],
#  ['sierra leone and an african union fund were moved to cap a draw organization believes they engaged\n'],
#  ['election experts abandon francois hollande to become a national party rally for the next two french foreign minister also\n'],
#  ['an advanced policy to explore the new of experience in china drive is worth\n'],
#  ['report finds global china is a big influence in the united nations on approval rating pew that\n'],
#  ['new some protesters are handed arriving in the indian embassy says they angry with a failed license twenty\n'],
#  ['report more than people have died from the united states of cardiac arrest at least\n'],
#  ['the outcry should be published by fact in probe of death as effects speed\n'],
#  ['tested are becoming more visual on itunes in the society judge said method would take nude mail and sexually\n'],
# ...
#  ['mullah omar khan has no un special detention in afghanistan pakistan at least six fighters are\n'],
#  ['small new future is getting more good checks it will split up to people they are also scheduled\n'],
#  ['serena williams pulls out of tears at clubhouse open in a australian simpson is first to come\n'],
#  ['new seized in kenya was to run over iraq officials say dan banks also lay off military aircraft\n'],
#  ['guinea and south korea will withdraw the central african republic president of un last year\n'],
#  ['new he vows to undermine philip seymour james m the legendary fact owes raymond clark tuesday christies but\n'],
#  ['rory mcilroy says he is a piece of palestinian leaders the most dangerous christopher d daniel\n'],
#  ['the cw told it almost always a series of weight with buzz at long schedule telling\n'],
#  ['peggy drexler saw movement working on the internet is days before end of social media closely and\n'],
#  ['passengers in japan introduce a new turning point about film overall crew members can pick out\n'],
#  ['new obama romney says the country wont lose comment on israeli foreign policy israel alleges iran is offensive against\n'],
#  ['ed rollins when i have the american seem little they answer comedian urges people we hope he\n'],
#  ['study found series of incidents over rise in mexico investigation into the case there were no deaths on july\n'],
#  ['justice department criminal investigation continues to file papers in los angeles cartels face the measure probe into allegations against\n'],
#  ['the study of labor workers saw worlds first female growth rising law in world bank limits authors\n'],
#  ['china says beijing advances in moscow as joint border north korea spying surveillance was effect\n'],
#  ['cnns morsys version of the gulf airlines sat down alabama students find part a factor in banning examples\n'],
#  ['frances national guard said he wants to sell about towns in afghanistan the us government and a group of\n'],
#  ['hassan nasrallah sits down the other drone attacks went cairo did not meet israeli prime\n'],
#  ['gop presidential hopeful its a big drop on race to rep ryan kelly or woman in\n'],
#  ['seven seized in stockholm on sunday baby had reported rescued couples with two being a girl athens\n'],
#  ['new jersey bans stricter immigration ban on gun control bill thursday national law proposals for nearly\n'],
#  ['the parents and her group have been given families through help from colorado school members put\n'],
#  ['two other men have demanded a better or coordinated more such <unk> says as\n'],
#  ['world no novak djokovic will pregnant after years at wimbledon the czech continue to leave miami quarterfinals\n'],
#  ['pakistani cricketers coached to india after leaving pakistan officials had said he an duty as a coach\n'],
#  ['bruce katz clark says he is long history in chicago schools doesnt want to live\n'],
#  ['george tiller was shot after being charged with two people in interview dr died while\n'],
#  ['new cuban forces continue to help with from tacloban denmark diverted most orders aid workers find troops\n'],
#  ['tax lot has already cost more than billion loan sales increase globally new british settlement plans for a\n'],
#  ['new gop source a key yahoo official jerry brown says his hardest by the va clinton was\n'],
#  ['ben and george williams ii are a key factor he says cost of the banks building\n'],
#  ['the actor and lee getting an appearance in caribbean film follows audience\n'],
#  ['martin kaymer takes on course at french open tennis tournament andy murray former world no roger federer arguing his\n'],
#  ['small areas of panama are still part the sensitive haul vessel discovered by famous fishing boat\n'],
#  ['this page includes the show transcript and daily curriculum use to help students with reading comprehension\n'],
#  ['the tournament fell after costa rica victory over marco rubio hosts argentina in mexico a win\n'],
#  ['new adam lanza was not been stabbed inside a recent report police project officer is said to have\n'],
#  ['new navy aircraft and another team took place during wednesdays delay official says ups helicopter is thursday looking at\n'],
#  ['police business issues spread to uk as the issue of result sales pulls\n'],
#  ['new police ask for how to have nothing make this long order prime minister says\n'],
#  ['james carville health troubles are part of obamas response she says the clintons issue is some bennett if they\n'],
#  ['some <unk> political activities are back on facebook the status is hosting its tourism trip iranian mubarak met saturday\n'],
#  ['rory mcilroy ends after european tour finals at arena on saturday rising star mark <unk> with the weekend\n'],
#  ['the winner of new years includes million no motto ideas be now most list\n'],
#  ['john thune new if youre that we spell as bad good avoid us cause of wet\n'],
#  ['us and japanese government are suspended pending further exports turkish says foreign minister it can ban\n'],
#  ['we are holding a colombian drug trafficking ed and spanish court says men free home for\n'],
#  ['i had to be years old when his father died katherine a roots with wife in\n'],
#  ['the formula one is still widely available by gap between technology seconds red cars speed\n'],
#  ['new zealand says the us shares an unusual encounter of tour swedish broad customs enforcement and\n'],
#  ['new defense agency had concluded airstrikes which occurred before jury panel drew <unk> case for long time was set\n'],
#  ['scientists reveal the planet that have occurred in california it is deep only of sea\n'],
#  ['new prince jackson in mr sense and i failed to show up michael mother says he tweets\n'],
#  ['from quentin tarantino to ken loach cannes is packed with big names critic jonathan romneys looking forward jane\n'],
#  ['football coach is ranked as the owner of love baseball season plays for a pet\n'],
#  ['new bush failed his victory for title world record book sells in german history and won\n'],
#  ['sex woman was sentenced to five years in prison for two other police say are\n'],
#  ['passenger plane involved didnt voice in hudson heartbreaking wait tv tickets when rolled out\n'],
#  ['atlanta became the first run yacht race in las vegas a day of wheel well clerks office teams\n'],
#  ['japanese manufacturer has a lasting shape of involving luxury car gathered in large tahrir square\n'],
#  ['us authorities issue reports that they see proof of visas in north korea colleagues say asked spots for\n'],
#  ['prosecutors say the ukrainian security forces have taken detained haitians in french air force acting sources consular teams\n'],
#  ['barcelona and england are secured their career title for european champions big win germany in monaco\n'],
#  ['new obama to step down calls be done call sen barack voters in\n'],
#  ['after being refused to kill someone treated at a mine outside facility around stands by\n'],
#  ['barcelona draw with david <unk> for in la liga opener ferrer elizabeth lionel messi files close after\n'],
#  ['french authorities sell boat damages to find million euros reveal members of the home say\n'],
#  ['new russian official says people had to show up their luggage blamed on natural seas after being diverted\n'],
#  ['this week trace james released all of the floor her collection photos examples things\n'],
#  ['the mob boss jimmy savile released and after leaving show artists are engaged in alleged assault sheriffs spokesman\n'],
#  ['the nfl for a fourth round game about behind candelabra <unk> robert downey jr claims he has\n'],
#  ['exhibition swedens visitors gallery features emperor prince charles display guitar succeeded in van as more than twothirds of his\n'],
#  ['jetblue airlines says will be on traveling its faa official however yet over state couples\n'],
#  ['new music awards is set at los angeles school band behind the singer brought themselves through to\n'],
#  ['web companies in sites after losing all legitimacy state activists say the banks became ill managers\n'],
#  ['new some people talk in the day about night george zimmerman speaks to president on\n'],
#  ['group claims people are being angry after netherlands man utd dutch manager just outside champions league\n'],
#  ['new judge denies bail for frank dipascali despite deal he had with prosecutors bernie madoffs fiance chief pleads\n'],
#  ['barcelona have won two best rivals atletico in group c scoring goals eight points of top table\n'],
#  ['a number of cash in debt was paid more than million bank the company says it\n'],
#  ['introducing military ships dedicated to parade with cards a used make soldiers the plot uses names\n'],
#  ['obama spoke to florence on billion spending in november the washington illinois and were delegates about its banking\n'],
#  ['republicans are expected to make their health coverage up less than phrases in obamacare you could get\n'],
#  ['renee zellweger plays character based on george hamiltons mother in new film says shes lucky generally young who\n'],
#  ['mother says report reported twin boys were on a road of girl\n'],
#  ['the number of presidential spokesman calls university texas staff hurt ill be posts for information anthony\n'],
#  ['british grand ole stop all four of the men hospitalized earlier this year tom cole came to five months\n'],
#  ['new extended relief operations were planned to be scheduled wednesday shuttle lands at a day before they released\n'],
#  ['democratic sen pat roberts is democrats choice against candidate greg orman says of his party or\n'],
#  ['the video used to show with dog its sister says hes posted shes online without\n'],
#  ['the fbi says three sites were found sunday earlier searching for days nearly discovered\n'],
#  ['the chinese artist said tycoon to drive manager says band plans share their art iconic\n'],
#  ['kabul hospitals operating budget is less than a month government pays salaries wages basic minister promises capital deal\n'],
#  ['porn actors and comedy the stars big changes to hijack film will continue through a sequel\n'],
#  ['colombia saw islamic groups backed top leaders on azerbaijan charges critical of protesters at least one bank offices were\n'],
#  ['<unk> shaun keith was only a first person to make up use of his car he admits\n'],
#  ['a us airways flight makes emergency landing in new york man says he was traveling to the\n'],
#  ['premier league leaders arsenal taken to the top of a beat on sunday\n'],
#  ['police catholic bishops cemetery statement made by prince church charities names priest hundreds of children\n'],
#  ['san antonio spurs draw with daniel roma and his rivals inter milan the lead city is home to a\n'],
#  ['bostons logan editor ahmed met with cnns piers morgan in social media he accused of making false guards\n'],
#  ['beverly berlin is one of the most famous fairy tales shed light on sharing digital value and films\n'],
#  ['polls show hillary clinton is a critical message clintons run sen ally\n'],
#  ['cnn readers share the why season drew pedrosa italian noaa said hoping to be following jules bianchi\n'],
#  ['freedom of rights commission does not recognize the civil proceeds in law they say reads\n'],
#  ['barcelona beat arsenal to claim a win at scoring match against the top of barca in\n'],
#  ['tropical storm vongfong is mph sustained close to warning expected as\n'],
#  ['do parents say they will so with these families message tend to pay tribute\n'],
#  ['new injured antonio lands in areas of ground homeless three others the explosion happened during\n'],
#  ['matthew miller died in fatal shooting two weeks after roommate we are full of identification he found the dead\n'],
#  ['chinese president ma talked to snowden down by businessman former international investors only paid more than ny allegations on\n'],
#  ['with million seats in the <unk> will compete price number has gone up to for\n'],
#  ['new the official says does not apologize to incident an spokesman\n'],
#  ['us masters is always held at prestigious augusta national georgia open bethpage state parks black course\n'],
#  ['<unk> nightlife is creator of internet support in video game screening room features serena williams tv\n'],
#  ['author jk rowling is making a potential list of cards five books the rapper wants bar for\n'],
#  ['paul webster there were many attempted suicide that was the second time of ordinary people killed when they\n'],
#  ['in new movie zombieland focus is on the stars and comedy movies performers include woody harrelson abigail breslin\n'],
#  ['more than people have died in ukraine operations libya a man on island board plane\n'],
#  ['college basketball coach shot his teacher on board shooter is safe he heard gunshots left eye by a\n'],
#  ['netflix has more than movies with billion subscribers are spent connected the stars\n'],
#  ['saudi authorities attacked a car bomb near border two roadside detonated ohio shootout with boko terror\n'],
#  ['several dead and people are among blame social media networks spends four days there no signs to being\n'],
#  ['new israeli reports russian economy vladimir putins dollars mentions will pay tribute to michael jacksons euros eve hour\n'],
#  ['thai prime minister calls on witnesses to return home early morning the just had killed by last\n'],
#  ['the couple of her children are very concerned about rape gadhafi family reportedly cant be with disappearance\n'],
#  ['president cristina fernandez de kirchner is a favorite count of italys barack obama visits italy the interests are\n'],
#  ['manchester city supporters face premier to serie a giants juventus owner out of the west cup as place\n'],
#  ['jim robinson what could be too much for our choices congressional negotiators are he says in agency\n'],
#  ['new police official says media was looking into the publication of it came years ago in china\n'],
#  ['nigerias president charged with helping in pakistan columbia he was wrongly convicted last of the icc samuel\n'],
#  ['tara sonenshine after congressional committee ran afoul of health he was also convicted terror groups and\n'],
#  ['barnes jennings is the musical as a handful of <unk> actor piece performance singer during\n'],
#  ['a passengers plane landed in an headed for took place after\n'],
#  ['ba working with us virgin atlantic airlines airways passenger says canadian earn tentative flight ahead of airline\n'],
#  ['google street is doing as running analyst says social networking founder <unk> investment group plan isnt recognized by\n'],
#  ['bill clinton lays on gay rights and plan to repeal his statement conservatives should not return months task\n'],
#  ['taylor swift returns to polls <unk> strikers performance she is happy about six nominations retains his title\n'],
#  ['jesse jackson jr stripped of haitian journalist who said she was arrested in march brazilian embassy\n'],
#  ['attorney says wellknown paleontologist will plead guilty to stealing dinosaur bones nate murphy of the judith river institute\n'],
#  ['lebron james is in chicago where best nba los angeles dodgers create\n'],
#  ['michigan health system requires football for a path to fallen by massachusetts student richard passed democrats so\n'],
#  ['photographer calls on <unk> create like mobile app founder called youtube the best work with nigerias\n'],
#  ['syrian air plane shot down fired into syria defense forces it is a great but would\n'],
#  ['we could take the same way as prime minister says is most of its projected\n'],
#  ['homeland security summit held in after elections chiefs union leader follows no group of hostages including arrest by\n'],
#  ['us victims have links to support in iraq each other player was countrys first female for\n'],
#  ['bob greene <unk> founder of an acclaimed career representative said he is playing tour atlanta employee richard knows\n'],
#  ['each found pieces of great crime shows <unk> is abraham tony the famous bandit has been in one\n'],
#  ['new at least people were evacuated from a house it will focus on without cruise ship oasis\n'],
#  ['man weighed in san antonio california hospital his wife says put them at a for one\n'],
#  ...]

# %%
clean_summaries[70000:]
# Out:
# ['sen john mccain says decision should be disturbing to all americans  analyst says voters favor the way obama has raised campaign cash  sen barack obama calls public finance system broken  move will allow obama to spend unlimited amount of money',
#  'mothers serves hearty breakfasts on the edge of the central business district  parkway bakery tavern is known for its po boy sandwiches  chef john besh celebrates regional ingredients in french style at august',
#  'the oceans are growing crowded and some scientists worry about ocean sprawl  for the first time governments plan ocean use in a comprehensive way  advocate says oceans are the last frontier for use and development  president obama creates task force to map out the future of the oceans',
#  'the daily transcript is a written version of each days cnn student news program  use this transcript to help students with reading comprehension and vocabulary  use the weekly newsquiz to test your knowledge of stories you saw on cnn student news',
#  'boko haram has attacked various targets in the nation since  mamadu bama is secondincommand of the islamist extremist group army says  he was killed along with his father who was the groups spiritual mentor',
#  'a total of soldiers were being tested for their expert field medical badge  of them suffer heatrelated illnesses  one is in intensive care  the difficulttoobtain badge is considered the portrait of excellence in the army',
#  'raul gonzalez scores two as real madrid beat sporting gijon on sunday  the goals ensure the breaks aldfredo di stefanos scoring record  reals eighth consecutive win closes gap on leaders barcelona to points',
#  'gloria borger herman cain seems to know little about national issues presidency  she says he hasnt adequately dealt with allegations of sexual harassment  cain seemed to have little sense of us policy on libya borger says  borger other gop candidates should challenge cain on his lack of fitness for candidacy',
#  'real madrid striker alvaro negredo completes his permanent move to sevilla  negredo has signed fiveyear contract although real have a buyback option  the highlyrated negredo scored goals while on loan to almeria last season',
#  'foreign ministry one person was rescued tuesday about hours after a distress call  it is unclear why the ship sank on monday  report the sunken vessel was hijacked by somali pirates in',
#  'demonstrators pack a stretch in buenos aires  the protests are known as cacerolazos named for the pots participants bang  protesters criticize president cristina fernandez de kirchners government  the constitution should be respected not reformed one organizer says',
#  'manchester police will not take action over cristiano ronaldo car crash  ronaldo wrote off his ferrari as he drove to training on january  no other vehicles were involved and ronaldo escaped injury',
#  'some websites are blacking out in protest of two controversial copyright bills in congress  andrew mcdiarmid stop online piracy act and protect ip act would undermine open internet  online backlash against the bills are forcing supporters to back down mcdiarmid says  mcdiarmid voting on the legislation should be delayed because it can be improved',
#  'the fan favorite comedy community returns for a sixth season on yahoo  the series is just as weirdly hilarious as ever with surprises in store  critics and fans loved the premiere',
#  'emma watson gives a rousing speech at the united nations about gender inequality  gayle lemmon watson is the latest star to illuminate the rebranding of feminism  she says that to date we have seen a lot of promise and much less progress  lemmon the hard part is to take action and make changes to create a fairer world',
#  'the bureau of land management says it will review accident other desert events  the california highway patrol says it will not file criminal charges against the driver  the driver says he is devastated by the incident  truck crash at the offroad desert race leaves eight people dead',
#  'zeta gulf cartels have been waging a bloody war in northeastern mexico  eight killed early sunday in tamaulipas state which borders texas gulf of mexico  state department warns us citizens about travel to mexico  ciudad juarez across from el paso remains mexico most violent city',
#  'the confederations cup tournament takes place in south africa this month  eight teams are involved in the tournament including spain italy and brazil  entry is limited to regional champions the world cup holders and the hosts',
#  'nintendo execs say precise sword controls will be in future zelda games  skyward sword was the first to have such controls  series creator shigeru miyamoto wants gamers to practice swordplay',
#  'new russian space chief says the six people aboard the iss have enough food to last  the unmanned rocket crashed in a remote area of siberia emergency officials say  the progress cargo freighter was taking supplies to the international space station  nasas space shuttle program came to an end last month',
#  'the washington monument suffered cracks in augusts earthquake  the monument has sunk inches since its completion in  the national geodetic survey will also look at other monuments in the capital',
#  'jun young su was arrested in november kcna reports  sources say the detainee is a koreanamerican businessman  the state department is working on the case with the swedish embassy in pyongyang  north korea has detained several americans in recent years',
#  'twotime indy winner was killed sunday at las vegas race  born in england he likened himself to richard the lionheart  he also was a bit superstitious  driver recalls dan wheldons growing maturity love of family',
#  'turkish officials say filtering is needed to protect kids from web content  we dont need protection marchers signs say  turkey rules not fooling anyone journalism group report says',
#  'one trooper is conscious after being shot  pennsylvania crime stoppers offers a reward to help find suspects  police have named the two officers shot in an ambush  one trooper died from gunshot wounds',
#  'house passes a measure also authorizing civil action against holder  house passes criminal contempt measure against attorney general eric holder  holder dismisses vote as politically motivated  at issue is whether holder complied with a subpoena from congressional investigators',
#  'the daily transcript is a written version of each days cnn student news program  use this transcript to help students with reading comprehension and vocabulary  use the weekly newsquiz to test your knowledge of stories you saw on cnn student news',
#  'scientists announce plans to sequence the entire genome of king richard iii  monarchs remains were found buried beneath a parking lot in english city of leicester in  tests may reveal richard iiis eye and hair color and predisposition to certain diseases  genome sequencing to be carried out before skeleton and samples are controversially reburied',
#  'new the commission members plan to visit the settlement where the miners lived  the commission will look into the conduct of lonmin mine unions and police  protests at the mine in the northwest killed people including two police officers  of those miners were killed in a clash with police',
#  'cnn posed questions for readers via a facebook app  click through the gallery to see responses to questions about foreign policy  new questions will be posted on the app through election day',
#  'the iwatch would have a curved screen and run on ios report says  the public has shown interest in smart watches on kickstarter  apple did not immediately respond to a request for comment',
#  'the falcons host the seahawks in the nfls divisional playoffs sunday  the team has been plagued with woes since the falcons formed years ago  player eugene robinson propositioned a cop for sex the night before super bowl xxxiii  quarterback michael vick served time for running a dogfighting ring',
#  'melinda gates international womens day started small a century ago  she says theres now global awareness of vital role of women in society economy  when women can direct family budget health care and education improve she says  gates empowered women are a source of progress want to take action',
#  'julian castro is a democratic rising star tapped by president to head hud  his appointment could help improve democratic standing with latinos texas voters  castro will face questions about hud funds steering it through housing market recovery  texas colleagues say castro has the right blend of experience to get the job done',
#  'cnn hero sal dimiceli has devoted his life to helping his fellow americans  through his nonprofit he has been able to give desperate people what they need to get by  dimiceli recession has put more and more people in need',
#  'a quarter of the european unions to yearolds are out of work  member states have agreed to job and training guarantee schemes  they also plan to roll out billion euros to the hardest hit countries  eu employment commissioner lazlo andor says there is no silver bullet',
#  'new jerseys largest firefighters union is now looking to honor sandy hook victims  firefighters have begun collecting donations for the sandy ground project  playgrounds are to be built in communities recovering from the storm  each playground is for a victim gunned down on december at school in connecticut',
#  'officials in northampton massachusetts say fires have killed people  structures numerous cars burned early sunday district attorney says  fires reported between and am da says  task force of local state federal fire officials investigating',
#  'pennsylvania republican has been in the senate for five terms  move would give democrats majority if franken takes office  republican party chief rips into specter  republicans have been angry over his support of stimulus plan',
#  'former australian prime minister edward gough whitlam has passed away  whitlam who was was australias longestlived prime minister  he is remembered for the international links he created',
#  'more than syrians have fled to neighboring lebanon un says  resentment toward syrian refugees is on the rise in lebanon  syrians say theyre destitute and face discrimination in new country  the syrians took our world away from us lebanese boy says',
